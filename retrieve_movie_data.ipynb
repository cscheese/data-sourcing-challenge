# %% [markdown]
# ### Import Required Libraries and Set Up Environment Variables

# %%
# Dependencies
import requests
import time
from dotenv import load_dotenv
import os
import pandas as pd
import json

# %%
# Set environment variables from the .env in the local environment
load_dotenv('.env')

nyt_api_key = os.getenv('NYT')
tmdb_api_key = os.getenv('TMDB')

# I really struggled to get the API's to work. 
#I used AskBCS where they were finally able to help me get this figured out. 
# print(nyt_api_key, tmdb_api_key)

# %% [markdown]
# ### Access the New York Times API

# %%
# Set the base URL
url = "https://api.nytimes.com/svc/search/v2/articlesearch.json?"

# Filter for movie reviews with "love" in the headline
# section_name should be "Movies"
# type_of_material should be "Review"
filter_query = 'section_name:"Movies" AND type_of_material:"Review" AND headline:"love"'

# Use a sort filter, sort by newest
sort = "newest"

# Select the following fields to return:
# headline, web_url, snippet, source, keywords, pub_date, byline, word_count
field_list = "headline,web_url,snippet,source,keywords,pub_date,byline,word_count"

# Search for reviews published between a begin and end date
begin_date = "20130101"
end_date = "20230531"

# Build URL
query_url = (
    f"{url}api-key={nyt_api_key}&begin_date={begin_date}&end_date={end_date}"
    + f'&fq={filter_query}&sort={sort}&fl={field_list}'
)

# %%
# print query url
# print(query_url)

#checking on the url

# %%
# Print `response_data variable`
reviews_df = requests.get(query_url).json()
reviews_df

#checking to see what response I am getting
# Out:
# {'status': 'OK',
#  'copyright': 'Copyright (c) 2024 The New York Times Company. All Rights Reserved.',
#  'response': {'docs': [{'web_url': 'https://www.nytimes.com/2023/05/25/movies/the-attachment-diaries-review.html',
#     'snippet': 'A gynecologist and her patient form a horrifyingly twisted connection in this batty, bloody Argentine melodrama.',
#     'source': 'The New York Times',
#     'headline': {'main': '‘The Attachment Diaries’ Review: Love, Sick',
#      'kicker': None,
#      'content_kicker': None,
#      'print_headline': 'The Attachment Diaries',
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [{'name': 'subject',
#       'value': 'Movies',
#       'rank': 1,
#       'major': 'N'},
#      {'name': 'creative_works',
#       'value': 'The Attachment Diaries (Movie)',
#       'rank': 2,
#       'major': 'N'},
#      {'name': 'persons',
#       'value': 'Diment, Valentin Javier',
#       'rank': 3,
#       'major': 'N'}],
#     'pub_date': '2023-05-25T11:00:03+0000',
#     'byline': {'original': 'By Jeannette Catsoulis',
#      'person': [{'firstname': 'Jeannette',
#        'middlename': None,
#        'lastname': 'Catsoulis',
#        'qualifier': None,
#        'title': None,
#        'role': 'reported',
#        'organization': '',
#        'rank': 1}],
#      'organization': None},
#     'word_count': 295},
#    {'web_url': 'https://www.nytimes.com/2023/05/04/movies/whats-love-got-to-do-with-it-review.html',
#     'snippet': 'Two childhood friends navigate cultural differences in this pleasantly uncontentious romantic comedy.',
#     'source': 'The New York Times',
#     'headline': {'main': 'Review: ‘What’s Love Got to Do With It?’ Probably a Lot',
#      'kicker': None,
#      'content_kicker': None,
#      'print_headline': 'What’s Love Got to Do With It?',
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [{'name': 'subject',
#       'value': 'Movies',
#       'rank': 1,
#       'major': 'N'},
#      {'name': 'persons', 'value': 'Kapur, Shekhar', 'rank': 2, 'major': 'N'},
#      {'name': 'persons', 'value': 'James, Lily', 'rank': 3, 'major': 'N'},
#      {'name': 'persons', 'value': 'Azmi, Shabana', 'rank': 4, 'major': 'N'},
#      {'name': 'persons', 'value': 'Thompson, Emma', 'rank': 5, 'major': 'N'}],
#     'pub_date': '2023-05-04T17:16:45+0000',
#     'byline': {'original': 'By Jeannette Catsoulis',
#      'person': [{'firstname': 'Jeannette',
#        'middlename': None,
#        'lastname': 'Catsoulis',
#        'qualifier': None,
#        'title': None,
#        'role': 'reported',
#        'organization': '',
#        'rank': 1}],
#      'organization': None},
#     'word_count': 287},
#    {'web_url': 'https://www.nytimes.com/2023/05/04/movies/you-can-live-forever-review.html',
#     'snippet': 'Religion comes between two girls falling in love in the 1990s in this sweet coming-of-age film bathed in grunge hues.',
#     'source': 'The New York Times',
#     'headline': {'main': '‘You Can Live Forever’ Review: Do You Love Me Now?',
#      'kicker': None,
#      'content_kicker': None,
#      'print_headline': 'You Can Live Forever',
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [{'name': 'subject',
#       'value': 'Movies',
#       'rank': 1,
#       'major': 'N'},
#      {'name': 'creative_works',
#       'value': 'You Can Live Forever (Movie)',
#       'rank': 2,
#       'major': 'N'},
#      {'name': 'persons', 'value': 'Slutsky, Mark', 'rank': 3, 'major': 'N'},
#      {'name': 'persons',
#       'value': 'Watts, Sarah (Film Director)',
#       'rank': 4,
#       'major': 'N'},
#      {'name': 'persons',
#       'value': "O'Driscoll, Anwen",
#       'rank': 5,
#       'major': 'N'},
#      {'name': 'persons',
#       'value': 'Laporte, June (Actor)',
#       'rank': 6,
#       'major': 'N'}],
#     'pub_date': '2023-05-04T11:00:08+0000',
#     'byline': {'original': 'By Elisabeth Vincentelli',
#      'person': [{'firstname': 'Elisabeth',
#        'middlename': None,
#        'lastname': 'Vincentelli',
#        'qualifier': None,
#        'title': None,
#        'role': 'reported',
#        'organization': '',
#        'rank': 1}],
#      'organization': None},
#     'word_count': 294},
#    {'web_url': 'https://www.nytimes.com/2023/04/21/movies/a-tourists-guide-to-love-review.html',
#     'snippet': 'Rachael Leigh Cook stars in this bland rom-com as a travel executive exploring Vietnam and getting over a breakup.',
#     'source': 'The New York Times',
#     'headline': {'main': '‘A Tourist’s Guide to Love’ Review: A Wearyingly Familiar Trip',
#      'kicker': None,
#      'content_kicker': None,
#      'print_headline': 'A Tourist’s  Guide to Love',
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [{'name': 'subject',
#       'value': 'Movies',
#       'rank': 1,
#       'major': 'N'},
#      {'name': 'creative_works',
#       'value': "A Tourist's Guide to Love (Movie)",
#       'rank': 2,
#       'major': 'N'},
#      {'name': 'persons', 'value': 'Tsuchida, Steven', 'rank': 3, 'major': 'N'},
#      {'name': 'persons',
#       'value': 'Cook, Rachael Leigh',
#       'rank': 4,
#       'major': 'N'}],
#     'pub_date': '2023-04-21T07:03:25+0000',
#     'byline': {'original': 'By Elisabeth Vincentelli',
#      'person': [{'firstname': 'Elisabeth',
#        'middlename': None,
#        'lastname': 'Vincentelli',
#        'qualifier': None,
#        'title': None,
#        'role': 'reported',
#        'organization': '',
#        'rank': 1}],
#      'organization': None},
#     'word_count': 276},
#    {'web_url': 'https://www.nytimes.com/2023/04/20/movies/other-peoples-children-review.html',
#     'snippet': 'A radiant Virginie Efira stars as a Parisian teacher who blissfully falls for a man and his 4-year-old daughter, complicating everyone’s lives.',
#     'source': 'The New York Times',
#     'headline': {'main': '‘Other People’s Children’ Review: True Romance',
#      'kicker': 'Critic’s pick',
#      'content_kicker': None,
#      'print_headline': 'Intoxicating Love With a Sobering Turn',
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [{'name': 'subject',
#       'value': 'Movies',
#       'rank': 1,
#       'major': 'N'},
#      {'name': 'persons',
#       'value': 'Zlotowski, Rebecca',
#       'rank': 2,
#       'major': 'N'},
#      {'name': 'creative_works',
#       'value': "Other People's Children (Movie)",
#       'rank': 3,
#       'major': 'N'}],
#     'pub_date': '2023-04-20T15:35:13+0000',
#     'byline': {'original': 'By Manohla Dargis',
#      'person': [{'firstname': 'Manohla',
#        'middlename': None,
#        'lastname': 'Dargis',
#        'qualifier': None,
#        'title': None,
#        'role': 'reported',
#        'organization': '',
#        'rank': 1}],
#      'organization': None},
#     'word_count': 801},
#    {'web_url': 'https://www.nytimes.com/2023/04/13/movies/one-true-loves-movie-review.html',
#     'snippet': 'A film adaptation of Taylor Jenkins Reid’s novel has potential for drama, but it stumbles on stock melodrama.',
#     'source': 'The New York Times',
#     'headline': {'main': '‘One True Loves’ Review: A Romance Lost at Sea',
#      'kicker': None,
#      'content_kicker': None,
#      'print_headline': 'One True Loves',
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [{'name': 'subject',
#       'value': 'Movies',
#       'rank': 1,
#       'major': 'N'},
#      {'name': 'persons',
#       'value': 'Bracey, Luke (1989- )',
#       'rank': 2,
#       'major': 'N'},
#      {'name': 'persons', 'value': 'Liu, Simu', 'rank': 3, 'major': 'N'},
#      {'name': 'persons',
#       'value': 'Reid, Taylor Jenkins',
#       'rank': 4,
#       'major': 'N'},
#      {'name': 'persons', 'value': 'Soo, Phillipa', 'rank': 5, 'major': 'N'},
#      {'name': 'persons', 'value': 'Fickman, Andy', 'rank': 6, 'major': 'N'},
#      {'name': 'creative_works',
#       'value': 'One True Loves (Movie)',
#       'rank': 7,
#       'major': 'N'}],
#     'pub_date': '2023-04-13T11:00:06+0000',
#     'byline': {'original': 'By Brandon Yu',
#      'person': [{'firstname': 'Brandon',
#        'middlename': None,
#        'lastname': 'Yu',
#        'qualifier': None,
#        'title': None,
#        'role': 'reported',
#        'organization': '',
#        'rank': 1}],
#      'organization': None},
#     'word_count': 320},
#    {'web_url': 'https://www.nytimes.com/2023/04/13/movies/the-lost-weekend-a-love-story-review.html',
#     'snippet': 'There’s not much Lennon music heard in this doc about his affair with May Pang, and given how much Pang trashes his wife, Yoko Ono, it’s no surprise it was withheld.',
#     'source': 'The New York Times',
#     'headline': {'main': '‘The Lost Weekend: A Love Story’ Review: When John Lennon Strayed',
#      'kicker': None,
#      'content_kicker': None,
#      'print_headline': 'The Lost Weekend:  A Love Story',
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [{'name': 'subject',
#       'value': 'Documentary Films and Programs',
#       'rank': 1,
#       'major': 'N'},
#      {'name': 'creative_works',
#       'value': 'The Lost Weekend: A Love Story (Movie)',
#       'rank': 2,
#       'major': 'N'},
#      {'name': 'persons', 'value': 'Pang, May', 'rank': 3, 'major': 'N'},
#      {'name': 'persons', 'value': 'Lennon, John', 'rank': 4, 'major': 'N'},
#      {'name': 'persons', 'value': 'Ono, Yoko', 'rank': 5, 'major': 'N'},
#      {'name': 'persons', 'value': 'Brandstein, Eve', 'rank': 6, 'major': 'N'},
#      {'name': 'persons',
#       'value': 'Kaufman, Richard S (Filmmaker)',
#       'rank': 7,
#       'major': 'N'},
#      {'name': 'persons',
#       'value': 'Samuels, Stuart (Filmmaker)',
#       'rank': 8,
#       'major': 'N'},
#      {'name': 'subject',
#       'value': 'Content Type: Personal Profile',
#       'rank': 9,
#       'major': 'N'},
#      {'name': 'subject',
#       'value': 'Pop and Rock Music',
#       'rank': 10,
#       'major': 'N'}],
#     'pub_date': '2023-04-13T11:00:03+0000',
#     'byline': {'original': 'By Glenn Kenny',
#      'person': [{'firstname': 'Glenn',
#        'middlename': None,
#        'lastname': 'Kenny',
#        'qualifier': None,
#        'title': None,
#        'role': 'reported',
#        'organization': '',
#        'rank': 1}],
#      'organization': None},
#     'word_count': 327},
#    {'web_url': 'https://www.nytimes.com/2023/03/30/movies/a-thousand-and-one-review.html',
#     'snippet': 'A mesmerizing Teyana Taylor stars in A.V. Rockwell’s feature directing debut, about motherhood and survival in a fast-changing city.',
#     'source': 'The New York Times',
#     'headline': {'main': '‘A Thousand and One’ Review: A New York Love Story',
#      'kicker': 'Critic’s Pick',
#      'content_kicker': None,
#      'print_headline': 'An Unbending Will Meets a Shifting City',
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [{'name': 'subject',
#       'value': 'Movies',
#       'rank': 1,
#       'major': 'N'},
#      {'name': 'creative_works',
#       'value': 'A Thousand and One (Movie)',
#       'rank': 2,
#       'major': 'N'},
#      {'name': 'persons',
#       'value': 'Rockwell, AV (Film Director)',
#       'rank': 3,
#       'major': 'N'},
#      {'name': 'persons',
#       'value': 'Taylor, Teyana (1990- )',
#       'rank': 4,
#       'major': 'N'}],
#     'pub_date': '2023-03-30T18:53:42+0000',
#     'byline': {'original': 'By Manohla Dargis',
#      'person': [{'firstname': 'Manohla',
#        'middlename': None,
#        'lastname': 'Dargis',
#        'qualifier': None,
#        'title': None,
#        'role': 'reported',
#        'organization': '',
#        'rank': 1}],
#      'organization': None},
#     'word_count': 971},
#    {'web_url': 'https://www.nytimes.com/2023/02/09/movies/your-place-or-mine-review.html',
#     'snippet': 'This humdrum Netflix romantic comedy features Reese Witherspoon and Ashton Kutcher as longtime friends with possibly hidden feelings for each other.',
#     'source': 'The New York Times',
#     'headline': {'main': '‘Your Place or Mine’ Review: Try Neither',
#      'kicker': None,
#      'content_kicker': None,
#      'print_headline': 'They Have a Humdrum Kind of Love',
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [{'name': 'subject',
#       'value': 'Movies',
#       'rank': 1,
#       'major': 'N'},
#      {'name': 'creative_works',
#       'value': 'Your Place or Mine (Movie)',
#       'rank': 2,
#       'major': 'N'},
#      {'name': 'persons',
#       'value': 'Witherspoon, Reese',
#       'rank': 3,
#       'major': 'N'},
#      {'name': 'persons', 'value': 'Kutcher, Ashton', 'rank': 4, 'major': 'N'},
#      {'name': 'persons',
#       'value': 'McKenna, Aline Brosh',
#       'rank': 5,
#       'major': 'N'}],
#     'pub_date': '2023-02-10T00:00:05+0000',
#     'byline': {'original': 'By Amy Nicholson',
#      'person': [{'firstname': 'Amy',
#        'middlename': None,
#        'lastname': 'Nicholson',
#        'qualifier': None,
#        'title': None,
#        'role': 'reported',
#        'organization': '',
#        'rank': 1}],
#      'organization': None},
#     'word_count': 569},
#    {'web_url': 'https://www.nytimes.com/2023/02/02/movies/love-in-the-time-of-fentanyl-review.html',
#     'snippet': 'To combat the overdose crisis, a group that includes former and current users open a safe consumption site where shooting up does not have to mean death.',
#     'source': 'The New York Times',
#     'headline': {'main': '‘Love in the Time of Fentanyl’ Review: Heartbreak, Death and Hope in Vancouver',
#      'kicker': None,
#      'content_kicker': None,
#      'print_headline': 'Love in the Time Of Fentanyl',
#      'name': None,
#      'seo': None,
#      'sub': None},
#     'keywords': [{'name': 'subject',
#       'value': 'Documentary Films and Programs',
#       'rank': 1,
#       'major': 'N'},
#      {'name': 'subject', 'value': 'Fentanyl', 'rank': 2, 'major': 'N'},
#      {'name': 'subject',
#       'value': 'Drug Abuse and Traffic',
#       'rank': 3,
#       'major': 'N'},
#      {'name': 'subject',
#       'value': 'Volunteers and Community Service',
#       'rank': 4,
#       'major': 'N'},
#      {'name': 'creative_works',
#       'value': 'Love in the Time of Fentanyl (Movie)',
#       'rank': 5,
#       'major': 'N'},
#      {'name': 'persons', 'value': 'Askey, Colin', 'rank': 6, 'major': 'N'},
#      {'name': 'glocations',
#       'value': 'Vancouver (British Columbia)',
#       'rank': 7,
#       'major': 'N'},
#      {'name': 'organizations',
#       'value': 'Overdose Prevention Society',
#       'rank': 8,
#       'major': 'N'}],
#     'pub_date': '2023-02-02T12:00:11+0000',
#     'byline': {'original': 'By Concepción de León',
#      'person': [{'firstname': 'Concepción',
#        'middlename': None,
#        'lastname': 'de León',
#        'qualifier': None,
#        'title': None,
#        'role': 'reported',
#        'organization': '',
#        'rank': 1}],
#      'organization': None},
#     'word_count': 306}],
#   'meta': {'hits': 344, 'offset': 0, 'time': 17}}}

# %%
# Trying to see how many rows and columns the data has
#rows, columns = reviews_df.shape
#print(f"The DataFrame has{rows} rows and {columns} columns.")

# %%
#reviews_df.info()
#looking at column names and data types

# %%
# Create an empty list to store the reviews
reviews_list = []

# loop through pages 0-19
for page_number in range(20):   

    # Set up the base query URL
    query_url = f"{url}api-key={nyt_api_key}&begin_date={begin_date}&end_date={end_date}"
   
    # create query with a page number
    query_url_with_page = f'{query_url}&page={page_number}'
       
    # API results show 10 articles at a time
    print(f"Checked page: {page_number}")
    
    # Make a "GET" request and retrieve the JSON
    reviews = requests.get(query_url_with_page).json()
            
    # Add a twelve second interval between queries to stay within API query limits
    time.sleep(12)
   
    if not reviews["response"]["docs"]:
        print(f"No results on page {page_number}")
        break  # Break from the loop if no results
    try:
        # If there are results, loop through and save each review
        for review in reviews["response"]["docs"]:
            reviews_list.append(reviews)
    except: 
        # Print the reviews added from the current page
        print(f"Page {page_number} reviews added to list.")

# I used Xpert and ChatGPT and looking at homework to generate this code
# Out:
# Checked page: 0
# Checked page: 1
# Checked page: 2
# Checked page: 3
# Checked page: 4
# Checked page: 5
# Checked page: 6
# Checked page: 7
# Checked page: 8
# Checked page: 9
# Checked page: 10
# Checked page: 11
# Checked page: 12
# Checked page: 13
# Checked page: 14
# Checked page: 15
# Checked page: 16
# Checked page: 17
# Checked page: 18
# Checked page: 19

# %%
# Preview the first 5 results in JSON format using json.dumps
# with the argument indent=4 to format the data

print(json.dumps(reviews_list[:5], indent=4))  

#print(json.dumps(reviews_list[:5], indent=4))
# I used Xpert and ChatGPT and looking at homework to generate this code
# Out:
# [
#     {
#         "status": "OK",
#         "copyright": "Copyright (c) 2024 The New York Times Company. All Rights Reserved.",
#         "response": {
#             "docs": [
#                 {
#                     "abstract": "The Swiss event replaced James Levine with the Finnish maestro Esa-Pekka Salonen, and the orchestra responded with a crisp performance.",
#                     "web_url": "https://www.nytimes.com/2015/07/21/arts/international/review-verbier-festival-recovers-in-style-with-finnish-maestro.html",
#                     "snippet": "The Swiss event replaced James Levine with the Finnish maestro Esa-Pekka Salonen, and the orchestra responded with a crisp performance.",
#                     "lead_paragraph": "VERBIER, Switzerland \u2014 No one could have been shocked when James Levine announced on July 10 that because of an ear infection, he would have to cancel his trip here, high in the Alps east of Geneva, to open the 22nd season of the Verbier Festival last Friday. This was to have been Mr. Levine\u2019s return to the festival orchestra, which he helped form in 2000 and directed until 2009, and his first performance outside New York since he resigned as music director of the Boston Symphony Orchestra in 2011 after a long run of cancellations because of physical ailments.",
#                     "source": "International New York Times",
#                     "multimedia": [
#                         {
#                             "rank": 0,
#                             "subtype": "watch308",
#                             "caption": null,
#                             "credit": null,
#                             "type": "image",
#                             "url": "images/2015/07/21/arts/international/21iht-verbier21/21iht-verbier21-watch308.jpg",
#                             "height": 348,
#                             "width": 312,
#                             "legacy": {},
#                             "subType": "watch308",
#                             "crop_name": "watch308"
#                         },
#                         {
#                             "rank": 0,
#                             "subtype": "watch268",
#                             "caption": null,
#                             "credit": null,
#                             "type": "image",
#                             "url": "images/2015/07/21/arts/international/21iht-verbier21/21iht-verbier21-watch268.jpg",
#                             "height": 303,
#                             "width": 272,
#                             "legacy": {},
#                             "subType": "watch268",
#                             "crop_name": "watch268"
#                         },
#                         {
#                             "rank": 0,
#                             "subtype": "wide",
#                             "caption": null,
#                             "credit": null,
#                             "type": "image",
#                             "url": "images/2015/07/21/arts/international/21iht-verbier21/21iht-verbier21-thumbWide.jpg",
#                             "height": 126,
#                             "width": 190,
#                             "legacy": {
#                                 "widewidth": 190,
#                                 "wideheight": 126,
#                                 "wide": "images/2015/07/21/arts/international/21iht-verbier21/21iht-verbier21-thumbWide.jpg"
#                             },
#                             "subType": "wide",
#                             "crop_name": "thumbWide"
#                         },
#                         {
#                             "rank": 0,
#                             "subtype": "videoThumb",
#                             "caption": null,
#                             "credit": null,
#                             "type": "image",
#                             "url": "images/2015/07/21/arts/international/21iht-verbier21/21iht-verbier21-videoThumb.jpg",
#                             "height": 50,
#                             "width": 75,
#                             "legacy": {},
#                             "subType": "videoThumb",
#                             "crop_name": "videoThumb"
#                         },
#                         {
#                             "rank": 0,
#                             "subtype": "videoLarge",
#                             "caption": null,
#                             "credit": null,
#                             "type": "image",
#                             "url": "images/2015/07/21/arts/international/21iht-verbier21/21iht-verbier21-videoLarge.jpg",
#                             "height": 507,
#                             "width": 768,
#                             "legacy": {},
#                             "subType": "videoLarge",
#                             "crop_name": "videoLarge"
#                         },
#                         {
#                             "rank": 0,
#                             "subtype": "mediumThreeByTwo210",
#                             "caption": null,
#                             "credit": null,
#                             "type": "image",
#                             "url": "images/2015/07/21/arts/international/21iht-verbier21/21iht-verbier21-mediumThreeByTwo210.jpg",
#                             "height": 140,
#                             "width": 210,
#                             "legacy": {},
#                             "subType": "mediumThreeByTwo210",
#                             "crop_name": "mediumThreeByTwo210"
#                         },
#                         {
#                             "rank": 0,
#                             "subtype": "mediumThreeByTwo225",
#                             "caption": null,
#                             "credit": null,
#                             "type": "image",
#                             "url": "images/2015/07/21/arts/international/21iht-verbier21/21iht-verbier21-mediumThreeByTwo225.jpg",
#                             "height": 150,
#                             "width": 225,
#                             "legacy": {},
#                             "subType": "mediumThreeByTwo225",
#                             "crop_name": "mediumThreeByTwo225"
#                         },
#                         {
#                             "rank": 0,
#                             "subtype": "mediumThreeByTwo440",
#                             "caption": null,
#                             "credit": null,
#                             "type": "image",
#                             "url": "images/2015/07/21/arts/international/21iht-verbier21/21iht-verbier21-mediumThreeByTwo440.jpg",
#                             "height": 293,
#                             "width": 440,
#                             "legacy": {},
#                             "subType": "mediumThreeByTwo440",
#                             "crop_name": "mediumThreeByTwo440"
#                         },
#                         {
#                             "rank": 0,
#                             "subtype": "mediumThreeByTwo252",
#                             "caption": null,
#                             "credit": null,
#                             "type": "image",
#                             "url": "images/2015/07/21/arts/international/21iht-verbier21/21iht-verbier21-mediumThreeByTwo252.jpg",
#                             "height": 168,
#                             "width": 252,
#                             "legacy": {},
#                             "subType": "mediumThreeByTwo252",
#                             "crop_name": "mediumThreeByTwo252"
#                         },
#                         {
#                             "rank": 0,
#                             "subtype": "mediumThreeByTwo378",
#                             "caption": null,
#                             "credit": null,
#                             "type": "image",
#                             "url": "images/2015/07/21/arts/international/21iht-verbier21/21iht-verbier21-mediumThreeByTwo378.jpg",
#                             "height": 252,
#                             "width": 378,
#                             "legacy": {},
#                             "subType": "mediumThreeByTwo378",
#                             "crop_name": "mediumThreeByTwo378"
#                         },
#                         {
#                             "rank": 0,
#                             "subtype": "facebookJumbo",
#                             "caption": null,
#                             "credit": null,
#                             "type": "image",
#                             "url": "images/2015/07/21/arts/international/21iht-verbier21/21iht-verbier21-facebookJumbo.jpg",
#                             "height": 550,
#                             "width": 1050,
#                             "legacy": {},
#                             "subType": "facebookJumbo",
#                             "crop_name": "facebookJumbo"
#                         },
#                         {
#                             "rank": 0,
#                             "subtype": "videoFifteenBySeven1305",
#                             "caption": null,
#                             "credit": null,
#                             "type": "image",
#                             "url": "images/2015/07/21/arts/international/21iht-verbier21/21iht-verbier21-videoFifteenBySeven1305.jpg",
#                             "height": 609,
#                             "width": 1305,
#                             "legacy": {},
#                             "subType": "videoFifteenBySeven1305",
#                             "crop_name": "videoFifteenBySeven1305"
#                         },
#                         {
#                             "rank": 0,
#                             "subtype": "videoFifteenBySeven2610",
#                             "caption": null,
#                             "credit": null,
#                             "type": "image",
#                             "url": "images/2015/07/21/arts/international/21iht-verbier21/21iht-verbier21-videoFifteenBySeven2610.jpg",
#                             "height": 1218,
#                             "width": 2610,
#                             "legacy": {},
#                             "subType": "videoFifteenBySeven2610",
#                             "crop_name": "videoFifteenBySeven2610"
#                         },
#                         {
#                             "rank": 0,
#                             "subtype": "miniMoth",
#                             "caption": null,
#                             "credit": null,
#                             "type": "image",
#                             "url": "images/2015/07/21/arts/international/21iht-verbier21/21iht-verbier21-miniMoth.jpg",
#                             "height": 70,
#                             "width": 151,
#                             "legacy": {},
#                             "subType": "miniMoth",
#                             "crop_name": "miniMoth"
#                         },
#                         {
#                             "rank": 0,
#                             "subtype": "windowsTile336H",
#                             "caption": null,
#                             "credit": null,
#                             "type": "image",
#                             "url": "images/2015/07/21/arts/international/21iht-verbier21/21iht-verbier21-windowsTile336H.jpg",
#                             "height": 336,
#                             "width": 694,
#                             "legacy": {},
#                             "subType": "windowsTile336H",
#                             "crop_name": "windowsTile336H"
#                         },
#                         {
#                             "rank": 0,
#                             "subtype": "xlarge",
#                             "caption": null,
#                             "credit": null,
#                             "type": "image",
#                             "url": "images/2015/07/21/arts/international/21iht-verbier21/21iht-verbier21-articleLarge.jpg",
#                             "height": 400,
#                             "width": 600,
#                             "legacy": {
#                                 "xlarge": "images/2015/07/21/arts/international/21iht-verbier21/21iht-verbier21-articleLarge.jpg",
#                                 "xlargewidth": 600,
#                                 "xlargeheight": 400
#                             },
#                             "subType": "xlarge",
#                             "crop_name": "articleLarge"
#                         },
#                         {
#                             "rank": 0,
#                             "subtype": "blog480",
#                             "caption": null,
#                             "credit": null,
#                             "type": "image",
#                             "url": "images/2015/07/21/arts/international/21iht-verbier21/21iht-verbier21-blog480.jpg",
#                             "height": 320,
#                             "width": 480,
#                             "legacy": {},
#                             "subType": "blog480",
#                             "crop_name": "blog480"
#                         },
#                         {
#                             "rank": 0,
#                             "subtype": "blog427",
#                             "caption": null,
#                             "credit": null,
#                             "type": "image",
#                             "url": "images/2015/07/21/arts/international/21iht-verbier21/21iht-verbier21-blog427.jpg",
#                             "height": 285,
#                             "width": 427,
#                             "legacy": {},
#                             "subType": "blog427",
#                             "crop_name": "blog427"
#                         },
#                         {
#                             "rank": 0,
#                             "subtype": "tmagArticle",
#                             "caption": null,
#                             "credit": null,
#                             "type": "image",
#                             "url": "images/2015/07/21/arts/international/21iht-verbier21/21iht-verbier21-tmagArticle.jpg",
#                             "height": 395,
#                             "width": 592,
#                             "legacy": {},
#                             "subType": "tmagArticle",
#                             "crop_name": "tmagArticle"
#                         },
#                         {
#                             "rank": 0,
#                             "subtype": "jumbo",
#                             "caption": null,
#                             "credit": null,
#                             "type": "image",
#                             "url": "images/2015/07/21/arts/international/21iht-verbier21/21iht-verbier21-jumbo.jpg",
#                             "height": 683,
#                             "width": 1024,
#                             "legacy": {},
#                             "subType": "jumbo",
#                             "crop_name": "jumbo"
#                         },
#                         {
#                             "rank": 0,
#                             "subtype": "blog225",
#                             "caption": null,
#                             "credit": null,
#                             "type": "image",
#                             "url": "images/2015/07/21/arts/international/21iht-verbier21/21iht-verbier21-blog225.jpg",
#                             "height": 150,
#                             "width": 225,
#                             "legacy": {},
#                             "subType": "blog225",
#                             "crop_name": "blog225"
#                         },
#                         {
#                             "rank": 0,
#                             "subtype": "master675",
#                             "caption": null,
#                             "credit": null,
#                             "type": "image",
#                             "url": "images/2015/07/21/arts/international/21iht-verbier21/21iht-verbier21-master675.jpg",
#                             "height": 450,
#                             "width": 675,
#                             "legacy": {},
#                             "subType": "master675",
#                             "crop_name": "master675"
#                         },
#                         {
#                             "rank": 0,
#                             "subtype": "master180",
#                             "caption": null,
#                             "credit": null,
#                             "type": "image",
#                             "url": "images/2015/07/21/arts/international/21iht-verbier21/21iht-verbier21-master180.jpg",
#                             "height": 120,
#                             "width": 180,
#                             "legacy": {},
#                             "subType": "master180",
#                             "crop_name": "master180"
#                         },
#                         {
#                             "rank": 0,
#                             "subtype": "popup",
#                             "caption": null,
#                             "credit": null,
#                             "type": "image",
#                             "url": "images/2015/07/21/arts/international/21iht-verbier21/21iht-verbier21-popup.jpg",
#                             "height": 433,
#                             "width": 650,
#                             "legacy": {},
#                             "subType": "popup",
#                             "crop_name": "popup"
#                         },
#                         {
#                             "rank": 0,
#                             "subtype": "blog533",
#                             "caption": null,
#                             "credit": null,
#                             "type": "image",
#                             "url": "images/2015/07/21/arts/international/21iht-verbier21/21iht-verbier21-blog533.jpg",
#                             "height": 355,
#                             "width": 533,
#                             "legacy": {},
#                             "subType": "blog533",
#                             "crop_name": "blog533"
#                         },
#                         {
#                             "rank": 0,
#                             "subtype": "tmagSF",
#                             "caption": null,
#                             "credit": null,
#                             "type": "image",
#                             "url": "images/2015/07/21/arts/international/21iht-verbier21/21iht-verbier21-tmagSF.jpg",
#                             "height": 241,
#                             "width": 362,
#                             "legacy": {},
#                             "subType": "tmagSF",
#                             "crop_name": "tmagSF"
#                         },
#                         {
#                             "rank": 0,
#                             "subtype": "slide",
#                             "caption": null,
#                             "credit": null,
#                             "type": "image",
#                             "url": "images/2015/07/21/arts/international/21iht-verbier21/21iht-verbier21-slide.jpg",
#                             "height": 400,
#                             "width": 600,
#                             "legacy": {},
#                             "subType": "slide",
#                             "crop_name": "slide"
#                         },
#                         {
#                             "rank": 0,
#                             "subtype": "superJumbo",
#                             "caption": null,
#                             "credit": null,
#                             "type": "image",
#                             "url": "images/2015/07/21/arts/international/21iht-verbier21/21iht-verbier21-superJumbo.jpg",
#                             "height": 1365,
#                             "width": 2048,
#                             "legacy": {},
#                             "subType": "superJumbo",
#                             "crop_name": "superJumbo"
#                         },
#                         {
#                             "rank": 0,
#                             "subtype": "master1050",
#                             "caption": null,
#                             "credit": null,
#                             "type": "image",
#                             "url": "images/2015/07/21/arts/international/21iht-verbier21/21iht-verbier21-master1050.jpg",
#                             "height": 700,
#                             "width": 1050,
#                             "legacy": {},
#                             "subType": "master1050",
#                             "crop_name": "master1050"
#                         },
#                         {
#                             "rank": 0,
#                             "subtype": "master495",
#                             "caption": null,
#                             "credit": null,
#                             "type": "image",
#                             "url": "images/2015/07/21/arts/international/21iht-verbier21/21iht-verbier21-master495.jpg",
#                             "height": 330,
#                             "width": 495,
#                             "legacy": {},
#                             "subType": "master495",
#                             "crop_name": "master495"
#                         },
#                         {
#                             "rank": 0,
#                             "subtype": "master315",
#                             "caption": null,
#                             "credit": null,
#                             "type": "image",
#                             "url": "images/2015/07/21/arts/international/21iht-verbier21/21iht-verbier21-master315.jpg",
#                             "height": 210,
#                             "width": 315,
#                             "legacy": {},
#                             "subType": "master315",
#                             "crop_name": "master315"
#                         },
#                         {
#                             "rank": 0,
#                             "subtype": "square320",
#                             "caption": null,
#                             "credit": null,
#                             "type": "image",
#                             "url": "images/2015/07/21/arts/international/21iht-verbier21/21iht-verbier21-square320.jpg",
#                             "height": 320,
#                             "width": 320,
#                             "legacy": {},
#                             "subType": "square320",
#                             "crop_name": "square320"
#                         },
#                         {
#                             "rank": 0,
#                             "subtype": "filmstrip",
#                             "caption": null,
#                             "credit": null,
#                             "type": "image",
#                             "url": "images/2015/07/21/arts/international/21iht-verbier21/21iht-verbier21-filmstrip.jpg",
#                             "height": 190,
#                             "width": 190,
#                             "legacy": {},
#                             "subType": "filmstrip",
#                             "crop_name": "filmstrip"
#                         },
#                         {
#                             "rank": 0,
#                             "subtype": "square640",
#                             "caption": null,
#                             "credit": null,
#                             "type": "image",
#                             "url": "images/2015/07/21/arts/international/21iht-verbier21/21iht-verbier21-square640.jpg",
#                             "height": 640,
#                             "width": 640,
#                             "legacy": {},
#                             "subType": "square640",
#                             "crop_name": "square640"
#                         },
#                         {
#                             "rank": 0,
#                             "subtype": "moth",
#                             "caption": null,
#                             "credit": null,
#                             "type": "image",
#                             "url": "images/2015/07/21/arts/international/21iht-verbier21/21iht-verbier21-moth.jpg",
#                             "height": 151,
#                             "width": 151,
#                             "legacy": {},
#                             "subType": "moth",
#                             "crop_name": "moth"
#                         },
#                         {
#                             "rank": 0,
#                             "subtype": "mediumSquare149",
#                             "caption": null,
#                             "credit": null,
#                             "type": "image",
#                             "url": "images/2015/07/21/arts/international/21iht-verbier21/21iht-verbier21-mediumSquare149.jpg",
#                             "height": 149,
#                             "width": 149,
#                             "legacy": {},
#                             "subType": "mediumSquare149",
#                             "crop_name": "mediumSquare149"
#                         },
#                         {
#                             "rank": 0,
#                             "subtype": "articleInline",
#                             "caption": null,
#                             "credit": null,
#                             "type": "image",
#                             "url": "images/2015/07/21/arts/international/21iht-verbier21/21iht-verbier21-articleInline.jpg",
#                             "height": 127,
#                             "width": 190,
#                             "legacy": {},
#                             "subType": "articleInline",
#                             "crop_name": "articleInline"
#                         },
#                         {
#                             "rank": 0,
#                             "subtype": "hpSmall",
#                             "caption": null,
#                             "credit": null,
#                             "type": "image",
#                             "url": "images/2015/07/21/arts/international/21iht-verbier21/21iht-verbier21-hpSmall.jpg",
#                             "height": 109,
#                             "width": 163,
#                             "legacy": {},
#                             "subType": "hpSmall",
#                             "crop_name": "hpSmall"
#                         },
#                         {
#                             "rank": 0,
#                             "subtype": "blogSmallInline",
#                             "caption": null,
#                             "credit": null,
#                             "type": "image",
#                             "url": "images/2015/07/21/arts/international/21iht-verbier21/21iht-verbier21-blogSmallInline.jpg",
#                             "height": 101,
#                             "width": 151,
#                             "legacy": {},
#                             "subType": "blogSmallInline",
#                             "crop_name": "blogSmallInline"
#                         },
#                         {
#                             "rank": 0,
#                             "subtype": "mediumFlexible177",
#                             "caption": null,
#                             "credit": null,
#                             "type": "image",
#                             "url": "images/2015/07/21/arts/international/21iht-verbier21/21iht-verbier21-mediumFlexible177.jpg",
#                             "height": 118,
#                             "width": 177,
#                             "legacy": {},
#                             "subType": "mediumFlexible177",
#                             "crop_name": "mediumFlexible177"
#                         },
#                         {
#                             "rank": 0,
#                             "subtype": "sfSpan",
#                             "caption": null,
#                             "credit": null,
#                             "type": "image",
#                             "url": "images/2015/07/21/arts/international/21iht-verbier21/21iht-verbier21-sfSpan.jpg",
#                             "height": 263,
#                             "width": 395,
#                             "legacy": {},
#                             "subType": "sfSpan",
#                             "crop_name": "sfSpan"
#                         },
#                         {
#                             "rank": 0,
#                             "subtype": "largeHorizontal375",
#                             "caption": null,
#                             "credit": null,
#                             "type": "image",
#                             "url": "images/2015/07/21/arts/international/21iht-verbier21/21iht-verbier21-largeHorizontal375.jpg",
#                             "height": 250,
#                             "width": 375,
#                             "legacy": {},
#                             "subType": "largeHorizontal375",
#                             "crop_name": "largeHorizontal375"
#                         },
#                         {
#                             "rank": 0,
#                             "subtype": "hpLarge",
#                             "caption": null,
#                             "credit": null,
#                             "type": "image",
#                             "url": "images/2015/07/21/arts/international/21iht-verbier21/21iht-verbier21-hpLarge.jpg",
#                             "height": 287,
#                             "width": 511,
#                             "legacy": {},
#                             "subType": "hpLarge",
#                             "crop_name": "hpLarge"
#                         },
#                         {
#                             "rank": 0,
#                             "subtype": "largeWidescreen573",
#                             "caption": null,
#                             "credit": null,
#                             "type": "image",
#                             "url": "images/2015/07/21/arts/international/21iht-verbier21/21iht-verbier21-largeWidescreen573.jpg",
#                             "height": 322,
#                             "width": 573,
#                             "legacy": {},
#                             "subType": "largeWidescreen573",
#                             "crop_name": "largeWidescreen573"
#                         },
#                         {
#                             "rank": 0,
#                             "subtype": "largeWidescreen1050",
#                             "caption": null,
#                             "credit": null,
#                             "type": "image",
#                             "url": "images/2015/07/21/arts/international/21iht-verbier21/21iht-verbier21-largeWidescreen1050.jpg",
#                             "height": 590,
#                             "width": 1050,
#                             "legacy": {},
#                             "subType": "largeWidescreen1050",
#                             "crop_name": "largeWidescreen1050"
#                         },
#                         {
#                             "rank": 0,
#                             "subtype": "videoSmall",
#                             "caption": null,
#                             "credit": null,
#                             "type": "image",
#                             "url": "images/2015/07/21/arts/international/21iht-verbier21/21iht-verbier21-videoSmall.jpg",
#                             "height": 281,
#                             "width": 500,
#                             "legacy": {},
#                             "subType": "videoSmall",
#                             "crop_name": "videoSmall"
#                         },
#                         {
#                             "rank": 0,
#                             "subtype": "videoHpMedium",
#                             "caption": null,
#                             "credit": null,
#                             "type": "image",
#                             "url": "images/2015/07/21/arts/international/21iht-verbier21/21iht-verbier21-videoHpMedium.jpg",
#                             "height": 211,
#                             "width": 375,
#                             "legacy": {},
#                             "subType": "videoHpMedium",
#                             "crop_name": "videoHpMedium"
#                         },
#                         {
#                             "rank": 0,
#                             "subtype": "videoSixteenByNine600",
#                             "caption": null,
#                             "credit": null,
#                             "type": "image",
#                             "url": "images/2015/07/21/arts/international/21iht-verbier21/21iht-verbier21-videoSixteenByNine600.jpg",
#                             "height": 338,
#                             "width": 600,
#                             "legacy": {},
#                             "subType": "videoSixteenByNine600",
#                             "crop_name": "videoSixteenByNine600"
#                         },
#                         {
#                             "rank": 0,
#                             "subtype": "videoSixteenByNine540",
#                             "caption": null,
#                             "credit": null,
#                             "type": "image",
#                             "url": "images/2015/07/21/arts/international/21iht-verbier21/21iht-verbier21-videoSixteenByNine540.jpg",
#                             "height": 304,
#                             "width": 540,
#                             "legacy": {},
#                             "subType": "videoSixteenByNine540",
#                             "crop_name": "videoSixteenByNine540"
#                         },
#                         {
#                             "rank": 0,
#                             "subtype": "videoSixteenByNine495",
#                             "caption": null,
#                             "credit": null,
#                             "type": "image",
#                             "url": "images/2015/07/21/arts/international/21iht-verbier21/21iht-verbier21-videoSixteenByNine495.jpg",
#                             "height": 278,
#                             "width": 495,
#                             "legacy": {},
#                             "subType": "videoSixteenByNine495",
#                             "crop_name": "videoSixteenByNine495"
#                         },
#                         {
#                             "rank": 0,
#                             "subtype": "videoSixteenByNine390",
#                             "caption": null,
#                             "credit": null,
#                             "type": "image",
#                             "url": "images/2015/07/21/arts/international/21iht-verbier21/21iht-verbier21-videoSixteenByNine390.jpg",
#                             "height": 219,
#                             "width": 390,
#                             "legacy": {},
#                             "subType": "videoSixteenByNine390",
#                             "crop_name": "videoSixteenByNine390"
#                         },
#                         {
#                             "rank": 0,
#                             "subtype": "videoSixteenByNine480",
#                             "caption": null,
#                             "credit": null,
#                             "type": "image",
#                             "url": "images/2015/07/21/arts/international/21iht-verbier21/21iht-verbier21-videoSixteenByNine480.jpg",
#                             "height": 270,
#                             "width": 480,
#                             "legacy": {},
#                             "subType": "videoSixteenByNine480",
#                             "crop_name": "videoSixteenByNine480"
#                         },
#                         {
#                             "rank": 0,
#                             "subtype": "videoSixteenByNine310",
#                             "caption": null,
#                             "credit": null,
#                             "type": "image",
#                             "url": "images/2015/07/21/arts/international/21iht-verbier21/21iht-verbier21-videoSixteenByNine310.jpg",
#                             "height": 174,
#                             "width": 310,
#                             "legacy": {},
#                             "subType": "videoSixteenByNine310",
#                             "crop_name": "videoSixteenByNine310"
#                         },
#                         {
#                             "rank": 0,
#                             "subtype": "videoSixteenByNine225",
#                             "caption": null,
#                             "credit": null,
#                             "type": "image",
#                             "url": "images/2015/07/21/arts/international/21iht-verbier21/21iht-verbier21-videoSixteenByNine225.jpg",
#                             "height": 126,
#                             "width": 225,
#                             "legacy": {},
#                             "subType": "videoSixteenByNine225",
#                             "crop_name": "videoSixteenByNine225"
#                         },
#                         {
#                             "rank": 0,
#                             "subtype": "videoSixteenByNine96",
#                             "caption": null,
#                             "credit": null,
#                             "type": "image",
#                             "url": "images/2015/07/21/arts/international/21iht-verbier21/21iht-verbier21-videoSixteenByNine96.jpg",
#                             "height": 54,
#                             "width": 96,
#                             "legacy": {},
#                             "subType": "videoSixteenByNine96",
#                             "crop_name": "videoSixteenByNine96"
#                         },
#                         {
#                             "rank": 0,
#                             "subtype": "videoSixteenByNine768",
#                             "caption": null,
#                             "credit": null,
#                             "type": "image",
#                             "url": "images/2015/07/21/arts/international/21iht-verbier21/21iht-verbier21-videoSixteenByNine768.jpg",
#                             "height": 432,
#                             "width": 768,
#                             "legacy": {},
#                             "subType": "videoSixteenByNine768",
#                             "crop_name": "videoSixteenByNine768"
#                         },
#                         {
#                             "rank": 0,
#                             "subtype": "videoSixteenByNine150",
#                             "caption": null,
#                             "credit": null,
#                             "type": "image",
#                             "url": "images/2015/07/21/arts/international/21iht-verbier21/21iht-verbier21-videoSixteenByNine150.jpg",
#                             "height": 84,
#                             "width": 150,
#                             "legacy": {},
#                             "subType": "videoSixteenByNine150",
#                             "crop_name": "videoSixteenByNine150"
#                         },
#                         {
#                             "rank": 0,
#                             "subtype": "videoSixteenByNine1050",
#                             "caption": null,
#                             "credit": null,
#                             "type": "image",
#                             "url": "images/2015/07/21/arts/international/21iht-verbier21/21iht-verbier21-videoSixteenByNine1050.jpg",
#                             "height": 591,
#                             "width": 1050,
#                             "legacy": {},
#                             "subType": "videoSixteenByNine1050",
#                             "crop_name": "videoSixteenByNine1050"
#                         },
#                         {
#                             "rank": 0,
#                             "subtype": "videoSixteenByNine3000",
#                             "caption": null,
#                             "credit": null,
#                             "type": "image",
#                             "url": "images/2015/07/21/arts/international/21iht-verbier21/21iht-verbier21-videoSixteenByNine3000.jpg",
#                             "height": 1687,
#                             "width": 3000,
#                             "legacy": {},
#                             "subType": "videoSixteenByNine3000",
#                             "crop_name": "videoSixteenByNine3000"
#                         },
#                         {
#                             "rank": 0,
#                             "subtype": "thumbnail",
#                             "caption": null,
#                             "credit": null,
#                             "type": "image",
#                             "url": "images/2015/07/21/arts/international/21iht-verbier21/21iht-verbier21-thumbStandard.jpg",
#                             "height": 75,
#                             "width": 75,
#                             "legacy": {
#                                 "thumbnail": "images/2015/07/21/arts/international/21iht-verbier21/21iht-verbier21-thumbStandard.jpg",
#                                 "thumbnailwidth": 75,
#                                 "thumbnailheight": 75
#                             },
#                             "subType": "thumbnail",
#                             "crop_name": "thumbStandard"
#                         },
#                         {
#                             "rank": 0,
#                             "subtype": "thumbLarge",
#                             "caption": null,
#                             "credit": null,
#                             "type": "image",
#                             "url": "images/2015/07/21/arts/international/21iht-verbier21/21iht-verbier21-thumbLarge.jpg",
#                             "height": 150,
#                             "width": 150,
#                             "legacy": {},
#                             "subType": "thumbLarge",
#                             "crop_name": "thumbLarge"
#                         },
#                         {
#                             "rank": 0,
#                             "subtype": "smallSquare252",
#                             "caption": null,
#                             "credit": null,
#                             "type": "image",
#                             "url": "images/2015/07/21/arts/international/21iht-verbier21/21iht-verbier21-smallSquare252.jpg",
#                             "height": 252,
#                             "width": 252,
#                             "legacy": {},
#                             "subType": "smallSquare252",
#                             "crop_name": "smallSquare252"
#                         },
#                         {
#                             "rank": 0,
#                             "subtype": "blogSmallThumb",
#                             "caption": null,
#                             "credit": null,
#                             "type": "image",
#                             "url": "images/2015/07/21/arts/international/21iht-verbier21/21iht-verbier21-blogSmallThumb.jpg",
#                             "height": 50,
#                             "width": 50,
#                             "legacy": {},
#                             "subType": "blogSmallThumb",
#                             "crop_name": "blogSmallThumb"
#                         },
#                         {
#                             "rank": 0,
#                             "subtype": "smallSquare168",
#                             "caption": null,
#                             "credit": null,
#                             "type": "image",
#                             "url": "images/2015/07/21/arts/international/21iht-verbier21/21iht-verbier21-smallSquare168.jpg",
#                             "height": 168,
#                             "width": 168,
#                             "legacy": {},
#                             "subType": "smallSquare168",
#                             "crop_name": "smallSquare168"
#                         }
#                     ],
#                     "headline": {
#                         "main": "Review: Verbier Festival Recovers in Style with Finnish Maestro",
#                         "kicker": "Critics Notebook",
#                         "content_kicker": null,
#                         "print_headline": "Verbier Festival Recovers in Style",
#                         "name": null,
#                         "seo": null,
#                         "sub": null
#                     },
#                     "keywords": [
#                         {
#                             "name": "glocations",
#                             "value": "Switzerland",
#                             "rank": 1,
#                             "major": "N"
#                         },
#                         {
#                             "name": "organizations",
#                             "value": "Metropolitan Opera",
#                             "rank": 2,
#                             "major": "N"
#                         },
#                         {
#                             "name": "organizations",
#                             "value": "Boston Symphony Orchestra",
#                             "rank": 3,
#                             "major": "N"
#                         },
#                         {
#                             "name": "subject",
#                             "value": "Verbier Festival",
#                             "rank": 4,
#                             "major": "N"
#                         }
#                     ],
#                     "pub_date": "2015-07-20T10:53:05+0000",
#                     "document_type": "article",
#                     "news_desk": "Culture",
#                     "section_name": "Arts",
#                     "subsection_name": "International Arts",
#                     "byline": {
#                         "original": "By James R. Oestreich",
#                         "person": [
#                             {
#                                 "firstname": "James",
#                                 "middlename": "R.",
#                                 "lastname": "Oestreich",
#                                 "qualifier": null,
#                                 "title": null,
#                                 "role": "reported",
#                                 "organization": "",
#                                 "rank": 1
#                             }
#                         ],
#                         "organization": null
#                     },
#                     "type_of_material": "News",
#                     "_id": "nyt://article/00000469-7157-5655-8cfc-664eecc662d8",
#                     "word_count": 1100,
#                     "uri": "nyt://article/00000469-7157-5655-8cfc-664eecc662d8"
#                 },
#                 {
#                     "abstract": "What the journey of a Union Pacific locomotive reveals about Trump\u2019s plans for the North American economy.",
#                     "web_url": "https://www.nytimes.com/2018/03/30/business/economy/trade-nafta-union-pacific.html",
#                     "snippet": "What the journey of a Union Pacific locomotive reveals about Trump\u2019s plans for the North American economy.",
#                     "lead_paragraph": "CHICAGO \u2014 If North America were a factory, Union Pacific would be its biggest conveyor belt.",
#                     "print_section": "B",
#                     "print_page": "1",
#                     "source": "The New York Times",
#                     "multimedia": [
#                         {
#                             "rank": 0,
#                             "subtype": "xlarge",
#                             "caption": null,
#                             "credit": null,
#                             "type": "image",
#                             "url": "images/2018/03/08/business/08DC-RAIL-1/merlin_133154307_fe8ff477-7189-469b-8b94-df65f7886d89-articleLarge.jpg",
#                             "height": 480,
#                             "width": 600,
#                             "legacy": {
#                                 "xlarge": "images/2018/03/08/business/08DC-RAIL-1/merlin_133154307_fe8ff477-7189-469b-8b94-df65f7886d89-articleLarge.jpg",
#                                 "xlargewidth": 600,
#                                 "xlargeheight": 480
#                             },
#                             "subType": "xlarge",
# ...
#                             "url": "images/2020/08/19/multimedia/audio-app-nwp/audio-app-nwp-videoSixteenByNine225-v3.png",
#                             "height": 126,
#                             "width": 225,
#                             "legacy": {},
#                             "subType": "videoSixteenByNine225",
#                             "crop_name": "videoSixteenByNine225"
#                         },
#                         {
#                             "rank": 0,
#                             "subtype": "videoSixteenByNine96",
#                             "caption": null,
#                             "credit": null,
#                             "type": "image",
#                             "url": "images/2020/08/19/multimedia/audio-app-nwp/audio-app-nwp-videoSixteenByNine96-v3.png",
#                             "height": 54,
#                             "width": 96,
#                             "legacy": {},
#                             "subType": "videoSixteenByNine96",
#                             "crop_name": "videoSixteenByNine96"
#                         },
#                         {
#                             "rank": 0,
#                             "subtype": "videoSixteenByNine3000",
#                             "caption": null,
#                             "credit": null,
#                             "type": "image",
#                             "url": "images/2020/08/19/multimedia/audio-app-nwp/audio-app-nwp-videoSixteenByNine3000-v2.png",
#                             "height": 1688,
#                             "width": 3000,
#                             "legacy": {},
#                             "subType": "videoSixteenByNine3000",
#                             "crop_name": "videoSixteenByNine3000"
#                         },
#                         {
#                             "rank": 0,
#                             "subtype": "videoSixteenByNine768",
#                             "caption": null,
#                             "credit": null,
#                             "type": "image",
#                             "url": "images/2020/08/19/multimedia/audio-app-nwp/audio-app-nwp-videoSixteenByNine768-v3.png",
#                             "height": 432,
#                             "width": 768,
#                             "legacy": {},
#                             "subType": "videoSixteenByNine768",
#                             "crop_name": "videoSixteenByNine768"
#                         },
#                         {
#                             "rank": 0,
#                             "subtype": "videoSixteenByNine150",
#                             "caption": null,
#                             "credit": null,
#                             "type": "image",
#                             "url": "images/2020/08/19/multimedia/audio-app-nwp/audio-app-nwp-videoSixteenByNine150-v3.png",
#                             "height": 84,
#                             "width": 150,
#                             "legacy": {},
#                             "subType": "videoSixteenByNine150",
#                             "crop_name": "videoSixteenByNine150"
#                         },
#                         {
#                             "rank": 0,
#                             "subtype": "videoSixteenByNineJumbo1600",
#                             "caption": null,
#                             "credit": null,
#                             "type": "image",
#                             "url": "images/2020/08/19/multimedia/audio-app-nwp/audio-app-nwp-videoSixteenByNineJumbo1600-v3.png",
#                             "height": 900,
#                             "width": 1600,
#                             "legacy": {},
#                             "subType": "videoSixteenByNineJumbo1600",
#                             "crop_name": "videoSixteenByNineJumbo1600"
#                         },
#                         {
#                             "rank": 0,
#                             "subtype": "miniMoth",
#                             "caption": null,
#                             "credit": null,
#                             "type": "image",
#                             "url": "images/2020/08/19/multimedia/audio-app-nwp/audio-app-nwp-miniMoth-v3.png",
#                             "height": 70,
#                             "width": 151,
#                             "legacy": {},
#                             "subType": "miniMoth",
#                             "crop_name": "miniMoth"
#                         },
#                         {
#                             "rank": 0,
#                             "subtype": "windowsTile336H",
#                             "caption": null,
#                             "credit": null,
#                             "type": "image",
#                             "url": "images/2020/08/19/multimedia/audio-app-nwp/audio-app-nwp-windowsTile336H-v3.png",
#                             "height": 336,
#                             "width": 694,
#                             "legacy": {},
#                             "subType": "windowsTile336H",
#                             "crop_name": "windowsTile336H"
#                         },
#                         {
#                             "rank": 0,
#                             "subtype": "videoFifteenBySeven1305",
#                             "caption": null,
#                             "credit": null,
#                             "type": "image",
#                             "url": "images/2020/08/19/multimedia/audio-app-nwp/audio-app-nwp-videoFifteenBySeven1305-v3.png",
#                             "height": 609,
#                             "width": 1305,
#                             "legacy": {},
#                             "subType": "videoFifteenBySeven1305",
#                             "crop_name": "videoFifteenBySeven1305"
#                         },
#                         {
#                             "rank": 0,
#                             "subtype": "videoFifteenBySeven2610",
#                             "caption": null,
#                             "credit": null,
#                             "type": "image",
#                             "url": "images/2020/08/19/multimedia/audio-app-nwp/audio-app-nwp-videoFifteenBySeven2610-v2.png",
#                             "height": 1218,
#                             "width": 2610,
#                             "legacy": {},
#                             "subType": "videoFifteenBySeven2610",
#                             "crop_name": "videoFifteenBySeven2610"
#                         },
#                         {
#                             "rank": 0,
#                             "subtype": "facebookJumbo",
#                             "caption": null,
#                             "credit": null,
#                             "type": "image",
#                             "url": "images/2020/08/19/multimedia/audio-app-nwp/audio-app-nwp-facebookJumbo-v3.png",
#                             "height": 550,
#                             "width": 1050,
#                             "legacy": {},
#                             "subType": "facebookJumbo",
#                             "crop_name": "facebookJumbo"
#                         },
#                         {
#                             "rank": 0,
#                             "subtype": "watch308",
#                             "caption": null,
#                             "credit": null,
#                             "type": "image",
#                             "url": "images/2020/08/19/multimedia/audio-app-nwp/audio-app-nwp-watch308-v3.png",
#                             "height": 348,
#                             "width": 312,
#                             "legacy": {},
#                             "subType": "watch308",
#                             "crop_name": "watch308"
#                         },
#                         {
#                             "rank": 0,
#                             "subtype": "watch268",
#                             "caption": null,
#                             "credit": null,
#                             "type": "image",
#                             "url": "images/2020/08/19/multimedia/audio-app-nwp/audio-app-nwp-watch268-v3.png",
#                             "height": 303,
#                             "width": 272,
#                             "legacy": {},
#                             "subType": "watch268",
#                             "crop_name": "watch268"
#                         },
#                         {
#                             "rank": 0,
#                             "subtype": "verticalTwoByThree735",
#                             "caption": null,
#                             "credit": null,
#                             "type": "image",
#                             "url": "images/2020/08/19/multimedia/audio-app-nwp/audio-app-nwp-verticalTwoByThree735-v3.png",
#                             "height": 1103,
#                             "width": 735,
#                             "legacy": {},
#                             "subType": "verticalTwoByThree735",
#                             "crop_name": "verticalTwoByThree735"
#                         },
#                         {
#                             "rank": 0,
#                             "subtype": "mobileMasterAt3x",
#                             "caption": null,
#                             "credit": null,
#                             "type": "image",
#                             "url": "images/2020/08/19/multimedia/audio-app-nwp/audio-app-nwp-mobileMasterAt3x-v3.png",
#                             "height": 1013,
#                             "width": 1800,
#                             "legacy": {},
#                             "subType": "mobileMasterAt3x",
#                             "crop_name": "mobileMasterAt3x"
#                         }
#                     ],
#                     "headline": {
#                         "main": "Episode Four: \u2018Here\u2019s Another Fun Thing You Can Do\u2019",
#                         "kicker": null,
#                         "content_kicker": null,
#                         "print_headline": null,
#                         "name": null,
#                         "seo": null,
#                         "sub": null
#                     },
#                     "keywords": [
#                         {
#                             "name": "subject",
#                             "value": "Education (K-12)",
#                             "rank": 1,
#                             "major": "N"
#                         },
#                         {
#                             "name": "subject",
#                             "value": "Parenting",
#                             "rank": 2,
#                             "major": "N"
#                         },
#                         {
#                             "name": "glocations",
#                             "value": "Boerum Hill (Brooklyn, NY)",
#                             "rank": 3,
#                             "major": "N"
#                         },
#                         {
#                             "name": "glocations",
#                             "value": "Cobble Hill (Brooklyn, NY)",
#                             "rank": 4,
#                             "major": "N"
#                         },
#                         {
#                             "name": "organizations",
#                             "value": "Serial Productions",
#                             "rank": 5,
#                             "major": "N"
#                         }
#                     ],
#                     "pub_date": "2020-08-13T10:00:04+0000",
#                     "document_type": "article",
#                     "news_desk": "Podcasts",
#                     "section_name": "Podcasts",
#                     "byline": {
#                         "original": "By Chana Joffe-Walt, Julie Snyder, Sarah Koenig, Neil Drumming, Ira Glass, Eve L. Ewing, Rachel Lissy and Stowe Nelson",
#                         "person": [
#                             {
#                                 "firstname": "Chana",
#                                 "middlename": null,
#                                 "lastname": "Joffe-Walt",
#                                 "qualifier": null,
#                                 "title": null,
#                                 "role": "reported",
#                                 "organization": "",
#                                 "rank": 1
#                             },
#                             {
#                                 "firstname": "Julie",
#                                 "middlename": null,
#                                 "lastname": "Snyder",
#                                 "qualifier": null,
#                                 "title": null,
#                                 "role": "reported",
#                                 "organization": "",
#                                 "rank": 2
#                             },
#                             {
#                                 "firstname": "Sarah",
#                                 "middlename": null,
#                                 "lastname": "Koenig",
#                                 "qualifier": null,
#                                 "title": null,
#                                 "role": "reported",
#                                 "organization": "",
#                                 "rank": 3
#                             },
#                             {
#                                 "firstname": "Neil",
#                                 "middlename": null,
#                                 "lastname": "Drumming",
#                                 "qualifier": null,
#                                 "title": null,
#                                 "role": "reported",
#                                 "organization": "",
#                                 "rank": 4
#                             },
#                             {
#                                 "firstname": "Ira",
#                                 "middlename": null,
#                                 "lastname": "Glass",
#                                 "qualifier": null,
#                                 "title": null,
#                                 "role": "reported",
#                                 "organization": "",
#                                 "rank": 5
#                             },
#                             {
#                                 "firstname": "Eve",
#                                 "middlename": "L.",
#                                 "lastname": "Ewing",
#                                 "qualifier": null,
#                                 "title": null,
#                                 "role": "reported",
#                                 "organization": "",
#                                 "rank": 6
#                             },
#                             {
#                                 "firstname": "Rachel",
#                                 "middlename": null,
#                                 "lastname": "Lissy",
#                                 "qualifier": null,
#                                 "title": null,
#                                 "role": "reported",
#                                 "organization": "",
#                                 "rank": 7
#                             },
#                             {
#                                 "firstname": "Stowe",
#                                 "middlename": null,
#                                 "lastname": "Nelson",
#                                 "qualifier": null,
#                                 "title": null,
#                                 "role": "reported",
#                                 "organization": "",
#                                 "rank": 8
#                             }
#                         ],
#                         "organization": null
#                     },
#                     "type_of_material": "News",
#                     "_id": "nyt://article/0000da03-1036-5d08-a9ce-97d0606b09b2",
#                     "word_count": 197,
#                     "uri": "nyt://article/0000da03-1036-5d08-a9ce-97d0606b09b2"
#                 }
#             ],
#             "meta": {
#                 "hits": 740113,
#                 "offset": 0,
#                 "time": 85
#             }
#         }
#     }
# ]

# %%
# Convert reviews_list to a Pandas DataFrame using json_normalize()
reviews_df = pd.json_normalize(reviews_list)

# Display the DataFrame
reviews_df
# Out:
#     status                                          copyright  \
# 0       OK  Copyright (c) 2024 The New York Times Company....
# 1       OK  Copyright (c) 2024 The New York Times Company....
# 2       OK  Copyright (c) 2024 The New York Times Company....
# 3       OK  Copyright (c) 2024 The New York Times Company....
# 4       OK  Copyright (c) 2024 The New York Times Company....
# ..     ...                                                ...
# 195     OK  Copyright (c) 2024 The New York Times Company....
# 196     OK  Copyright (c) 2024 The New York Times Company....
# 197     OK  Copyright (c) 2024 The New York Times Company....
# 198     OK  Copyright (c) 2024 The New York Times Company....
# 199     OK  Copyright (c) 2024 The New York Times Company....
#
#                                          response.docs  response.meta.hits  \
# 0    [{'abstract': 'The Swiss event replaced James ...              740113
# 1    [{'abstract': 'The Swiss event replaced James ...              740113
# 2    [{'abstract': 'The Swiss event replaced James ...              740113
# 3    [{'abstract': 'The Swiss event replaced James ...              740113
# 4    [{'abstract': 'The Swiss event replaced James ...              740113
# ..                                                 ...                 ...
# 195  [{'abstract': 'The gunman used a semiautomatic...              740113
# 196  [{'abstract': 'The gunman used a semiautomatic...              740113
# 197  [{'abstract': 'The gunman used a semiautomatic...              740113
# 198  [{'abstract': 'The gunman used a semiautomatic...              740113
# 199  [{'abstract': 'The gunman used a semiautomatic...              740113
#
#      response.meta.offset  response.meta.time
# 0                       0                  85
# 1                       0                  85
# 2                       0                  85
# 3                       0                  85
# 4                       0                  85
# ..                    ...                 ...
# 195                   190                  84
# 196                   190                  84
# 197                   190                  84
# 198                   190                  84
# 199                   190                  84
#
# [200 rows x 6 columns]

# %%
# Trying to see how many rows and columns the data has
rows, columns = reviews_df.shape
print(f"The DataFrame has{rows} rows and {columns} columns.")
# Out:
# The DataFrame has200 rows and 6 columns.

# %%
# Convert reviews_list to a Pandas DataFrame using json_normalize()

from pandas import json_normalize

# Convert results_list to a Pandas DataFrame
reviews_df = json_normalize(reviews_list)

# Display the DataFrame
reviews_df
# Out:
#     status                                          copyright  \
# 0       OK  Copyright (c) 2024 The New York Times Company....
# 1       OK  Copyright (c) 2024 The New York Times Company....
# 2       OK  Copyright (c) 2024 The New York Times Company....
# 3       OK  Copyright (c) 2024 The New York Times Company....
# 4       OK  Copyright (c) 2024 The New York Times Company....
# ..     ...                                                ...
# 195     OK  Copyright (c) 2024 The New York Times Company....
# 196     OK  Copyright (c) 2024 The New York Times Company....
# 197     OK  Copyright (c) 2024 The New York Times Company....
# 198     OK  Copyright (c) 2024 The New York Times Company....
# 199     OK  Copyright (c) 2024 The New York Times Company....
#
#                                          response.docs  response.meta.hits  \
# 0    [{'abstract': 'The Swiss event replaced James ...              740113
# 1    [{'abstract': 'The Swiss event replaced James ...              740113
# 2    [{'abstract': 'The Swiss event replaced James ...              740113
# 3    [{'abstract': 'The Swiss event replaced James ...              740113
# 4    [{'abstract': 'The Swiss event replaced James ...              740113
# ..                                                 ...                 ...
# 195  [{'abstract': 'The gunman used a semiautomatic...              740113
# 196  [{'abstract': 'The gunman used a semiautomatic...              740113
# 197  [{'abstract': 'The gunman used a semiautomatic...              740113
# 198  [{'abstract': 'The gunman used a semiautomatic...              740113
# 199  [{'abstract': 'The gunman used a semiautomatic...              740113
#
#      response.meta.offset  response.meta.time
# 0                       0                  80
# 1                       0                  80
# 2                       0                  80
# 3                       0                  80
# 4                       0                  80
# ..                    ...                 ...
# 195                   190                  88
# 196                   190                  88
# 197                   190                  88
# 198                   190                  88
# 199                   190                  88
#
# [200 rows x 6 columns]

# %%
# Convert reviews_list to a Pandas DataFrame using json_normalize()

import pandas as pd
from pandas import json_normalize

# Convert results_list to a Pandas DataFrame
reviews_df = json_normalize(reviews_list)

# Display the DataFrame
reviews_df
# Out:
#                                               abstract  \
# 0    The Swiss event replaced James Levine with the...
# 1    What the journey of a Union Pacific locomotive...
# 2    State Department officials said the move was a...
# 3    Raking in cash for Biden, the former president...
# 4    Banks have tightened standards, becoming more ...
# ..                                                 ...
# 195  Iceland, the smallest nation ever to compete a...
# 196  The U.S. withdrew its forces from Afghanistan ...
# 197  The episode began with a report of a $20 count...
# 198  Ross Lovegrove, a British product designer, te...
# 199  Paul Giamatti and Paul Rudd play professional ...
#
#                                                web_url  \
# 0    https://www.nytimes.com/2015/07/21/arts/intern...
# 1    https://www.nytimes.com/2018/03/30/business/ec...
# 2    https://www.nytimes.com/2020/08/13/us/politics...
# 3    https://www.nytimes.com/2020/07/30/us/politics...
# 4    https://www.nytimes.com/2020/08/04/your-money/...
# ..                                                 ...
# 195  https://www.nytimes.com/2016/06/23/sports/socc...
# 196  https://www.nytimes.com/2022/02/10/opinion/bid...
# 197  https://www.nytimes.com/2020/05/29/us/derek-ch...
# 198  https://wheels.blogs.nytimes.com/2013/04/09/re...
# 199  https://www.nytimes.com/2013/10/04/movies/all-...
#
#                                                snippet  \
# 0    The Swiss event replaced James Levine with the...
# 1    What the journey of a Union Pacific locomotive...
# 2    State Department officials said the move was a...
# 3    Raking in cash for Biden, the former president...
# 4    Banks have tightened standards, becoming more ...
# ..                                                 ...
# 195  Iceland, the smallest nation ever to compete a...
# 196  The U.S. withdrew its forces from Afghanistan ...
# 197  The episode began with a report of a $20 count...
# 198  Ross Lovegrove, a British product designer, te...
# 199  Paul Giamatti and Paul Rudd play professional ...
#
#                                         lead_paragraph  \
# 0    VERBIER, Switzerland — No one could have been ...
# 1    CHICAGO — If North America were a factory, Uni...
# 2    WASHINGTON — The State Department announced on...
# 3    Obama takes the gloves off for Biden, and Cong...
# 4    As public school teachers, Tori Smith and her ...
# ..                                                 ...
# 195  A late winning goal. A spot in the knockout st...
# 196  U.S. troops in Iraq quietly thwarted two separ...
# 197  MINNEAPOLIS — One was a veteran of the Minneap...
# 198  Renault unveiled a striking blue concept car b...
# 199  The wry tone of “All Is Bright,” a sardonic, s...
#
#                            source  \
# 0    International New York Times
# 1              The New York Times
# 2              The New York Times
# 3              The New York Times
# 4              The New York Times
# ..                            ...
# 195            The New York Times
# 196            The New York Times
# 197            The New York Times
# 198            The New York Times
# 199            The New York Times
#
#                                             multimedia  \
# 0    [{'rank': 0, 'subtype': 'watch308', 'caption':...
# 1    [{'rank': 0, 'subtype': 'xlarge', 'caption': N...
# 2    [{'rank': 0, 'subtype': 'xlarge', 'caption': N...
# 3    [{'rank': 0, 'subtype': 'xlarge', 'caption': N...
# 4    [{'rank': 0, 'subtype': 'xlarge', 'caption': N...
# ..                                                 ...
# 195  [{'rank': 0, 'subtype': 'watch308', 'caption':...
# 196  [{'rank': 0, 'subtype': 'xlarge', 'caption': N...
# 197  [{'rank': 0, 'subtype': 'xlarge', 'caption': N...
# 198                                                 []
# 199  [{'rank': 0, 'subtype': 'wide', 'caption': Non...
#
#                                               keywords  \
# 0    [{'name': 'glocations', 'value': 'Switzerland'...
# 1    [{'name': 'organizations', 'value': 'Union Pac...
# 2    [{'name': 'subject', 'value': 'Chinese Languag...
# 3    [{'name': 'persons', 'value': 'Obama, Barack',...
# 4    [{'name': 'subject', 'value': 'Mortgages', 'ra...
# ..                                                 ...
# 195  [{'name': 'subject', 'value': 'Soccer', 'rank'...
# 196  [{'name': 'subject', 'value': 'Iraq War (2003-...
# 197  [{'name': 'persons', 'value': 'Floyd, George (...
# 198  [{'name': 'subject', 'value': 'Art', 'rank': 1...
# 199  [{'name': 'subject', 'value': 'Movies', 'rank'...
#
#                      pub_date document_type   news_desk  ...  \
# 0    2015-07-20T10:53:05+0000       article     Culture  ...
# 1    2018-03-30T21:31:00+0000       article    Business  ...
# 2    2020-08-13T22:14:24+0000       article  Washington  ...
# 3    2020-07-30T11:26:42+0000       article    Politics  ...
# 4    2020-08-04T15:29:25+0000       article    Business  ...
# ..                        ...           ...         ...  ...
# 195  2016-06-23T00:50:24+0000       article      Sports  ...
# 196  2022-02-10T21:21:24+0000       article        OpEd  ...
# 197  2020-05-29T23:48:27+0000       article    National  ...
# 198  2013-04-09T18:38:32+0000       article              ...
# 199  2013-10-03T22:29:10+0000       article     Weekend  ...
#
#     headline.content_kicker  \
# 0                      None
# 1                      None
# 2                      None
# 3                      None
# 4                      None
# ..                      ...
# 195                    None
# 196                    None
# 197                    None
# 198                    None
# 199                    None
#
#                                headline.print_headline headline.name  \
# 0                   Verbier Festival Recovers in Style          None
# 1    It Nourishes the Continent. Now Its Lifeblood ...          None
# 2                                                 None          None
# 3                                                 None          None
# 4           Borrowing Is Cheap. The Catch? Qualifying.          None
# ..                                                 ...           ...
# 195                  With Late Goal,  Iceland Advances          None
# 196                       U.S. Forces Should Exit Iraq          None
# 197    Fatal Encounter Wasn’t First Time Paths Crossed          None
# 198      Renault Shows Concept At Milan Furniture Fair          None
# 199             Sell Them Trees, Then Steal Them Blind          None
#
#     headline.seo  headline.sub  \
# 0           None          None
# 1           None          None
# 2           None          None
# 3           None          None
# 4           None          None
# ..           ...           ...
# 195         None          None
# 196         None          None
# 197         None          None
# 198         None          None
# 199         None          None
#
#                                        byline.original  \
# 0                                By James R. Oestreich
# 1                                       By Ana Swanson
# 2                                       By Edward Wong
# 3                               By Giovanni Russonello
# 4                               By Tara Siegel Bernard
# ..                                                 ...
# 195                                               None
# 196               By Trita Parsi and Adam N. Weinstein
# 197  By Matt Furber, Audra D. S. Burch and Frances ...
# 198                                     By Phil Patton
# 199                                  By Stephen Holden
#
#                                          byline.person byline.organization  \
# 0    [{'firstname': 'James', 'middlename': 'R.', 'l...                None
# 1    [{'firstname': 'Ana', 'middlename': None, 'las...                None
# 2    [{'firstname': 'Edward', 'middlename': None, '...                None
# 3    [{'firstname': 'Giovanni', 'middlename': None,...                None
# 4    [{'firstname': 'Tara', 'middlename': 'Siegel',...                None
# ..                                                 ...                 ...
# 195                                                 []                None
# 196  [{'firstname': 'Trita', 'middlename': None, 'l...                None
# 197  [{'firstname': 'Matt', 'middlename': None, 'la...                None
# 198  [{'firstname': 'Phil', 'middlename': None, 'la...                None
# 199  [{'firstname': 'Stephen', 'middlename': None, ...                None
#
#     print_section print_page
# 0             NaN        NaN
# 1               B          1
# 2             NaN        NaN
# 3             NaN        NaN
# 4               B          1
# ..            ...        ...
# 195             B         10
# 196             A         26
# 197             A          1
# 198            AU          3
# 199             C         15
#
# [200 rows x 28 columns]

# %%
reviews_df.columns
#I added this additional step so I could see all of the columns
# Out:
# Index(['abstract', 'web_url', 'snippet', 'lead_paragraph', 'source',
#        'multimedia', 'keywords', 'pub_date', 'document_type', 'news_desk',
#        'section_name', 'subsection_name', 'type_of_material', '_id',
#        'word_count', 'uri', 'headline.main', 'headline.kicker',
#        'headline.content_kicker', 'headline.print_headline', 'headline.name',
#        'headline.seo', 'headline.sub', 'byline.original', 'byline.person',
#        'byline.organization', 'print_section', 'print_page'],
#       dtype='object')

# %%
print(reviews_df['headline.main'])
# I added this additional step so I could see what was in the column 'headline.main'
# Out:
# 0      Review: Verbier Festival Recovers in Style wit...
# 1      ‘It’s Factory North America,’ but Trump Could ...
# 2      U.S. Labels Chinese Language Education Group a...
# 3                          Obama (Privately) Slams Trump
# 4      Interest Rates Are Low, but Loans Are Harder t...
#                              ...
# 195             Iceland Advances at Euros With Late Goal
# 196               Why Are American Troops Still in Iraq?
# 197    What Happened in the Chaotic Moments Before Ge...
# 198    Renault Shows Edgy Concept at Milan Furniture ...
# 199               Sell Them Trees, Then Steal Them Blind
# Name: headline.main, Length: 200, dtype: object

# %%
# Extract the title from the "headline.main" column and
# save it to a new column "title"
# Title is between unicode characters \u2018 and \u2019. 
# End string should include " Review" to avoid cutting title early
reviews_df["title"] = reviews_df["headline.main"].apply(lambda st: st[st.find("\u2018")+1:st.find("\u2019 Review")])
reviews_df
# Out:
#                                               abstract  \
# 0    The Swiss event replaced James Levine with the...
# 1    What the journey of a Union Pacific locomotive...
# 2    State Department officials said the move was a...
# 3    Raking in cash for Biden, the former president...
# 4    Banks have tightened standards, becoming more ...
# ..                                                 ...
# 195  Iceland, the smallest nation ever to compete a...
# 196  The U.S. withdrew its forces from Afghanistan ...
# 197  The episode began with a report of a $20 count...
# 198  Ross Lovegrove, a British product designer, te...
# 199  Paul Giamatti and Paul Rudd play professional ...
#
#                                                web_url  \
# 0    https://www.nytimes.com/2015/07/21/arts/intern...
# 1    https://www.nytimes.com/2018/03/30/business/ec...
# 2    https://www.nytimes.com/2020/08/13/us/politics...
# 3    https://www.nytimes.com/2020/07/30/us/politics...
# 4    https://www.nytimes.com/2020/08/04/your-money/...
# ..                                                 ...
# 195  https://www.nytimes.com/2016/06/23/sports/socc...
# 196  https://www.nytimes.com/2022/02/10/opinion/bid...
# 197  https://www.nytimes.com/2020/05/29/us/derek-ch...
# 198  https://wheels.blogs.nytimes.com/2013/04/09/re...
# 199  https://www.nytimes.com/2013/10/04/movies/all-...
#
#                                                snippet  \
# 0    The Swiss event replaced James Levine with the...
# 1    What the journey of a Union Pacific locomotive...
# 2    State Department officials said the move was a...
# 3    Raking in cash for Biden, the former president...
# 4    Banks have tightened standards, becoming more ...
# ..                                                 ...
# 195  Iceland, the smallest nation ever to compete a...
# 196  The U.S. withdrew its forces from Afghanistan ...
# 197  The episode began with a report of a $20 count...
# 198  Ross Lovegrove, a British product designer, te...
# 199  Paul Giamatti and Paul Rudd play professional ...
#
#                                         lead_paragraph  \
# 0    VERBIER, Switzerland — No one could have been ...
# 1    CHICAGO — If North America were a factory, Uni...
# 2    WASHINGTON — The State Department announced on...
# 3    Obama takes the gloves off for Biden, and Cong...
# 4    As public school teachers, Tori Smith and her ...
# ..                                                 ...
# 195  A late winning goal. A spot in the knockout st...
# 196  U.S. troops in Iraq quietly thwarted two separ...
# 197  MINNEAPOLIS — One was a veteran of the Minneap...
# 198  Renault unveiled a striking blue concept car b...
# 199  The wry tone of “All Is Bright,” a sardonic, s...
#
#                            source  \
# 0    International New York Times
# 1              The New York Times
# 2              The New York Times
# 3              The New York Times
# 4              The New York Times
# ..                            ...
# 195            The New York Times
# 196            The New York Times
# 197            The New York Times
# 198            The New York Times
# 199            The New York Times
#
#                                             multimedia  \
# 0    [{'rank': 0, 'subtype': 'watch308', 'caption':...
# 1    [{'rank': 0, 'subtype': 'xlarge', 'caption': N...
# 2    [{'rank': 0, 'subtype': 'xlarge', 'caption': N...
# 3    [{'rank': 0, 'subtype': 'xlarge', 'caption': N...
# 4    [{'rank': 0, 'subtype': 'xlarge', 'caption': N...
# ..                                                 ...
# 195  [{'rank': 0, 'subtype': 'watch308', 'caption':...
# 196  [{'rank': 0, 'subtype': 'xlarge', 'caption': N...
# 197  [{'rank': 0, 'subtype': 'xlarge', 'caption': N...
# 198                                                 []
# 199  [{'rank': 0, 'subtype': 'wide', 'caption': Non...
#
#                                               keywords  \
# 0    [{'name': 'glocations', 'value': 'Switzerland'...
# 1    [{'name': 'organizations', 'value': 'Union Pac...
# 2    [{'name': 'subject', 'value': 'Chinese Languag...
# 3    [{'name': 'persons', 'value': 'Obama, Barack',...
# 4    [{'name': 'subject', 'value': 'Mortgages', 'ra...
# ..                                                 ...
# 195  [{'name': 'subject', 'value': 'Soccer', 'rank'...
# 196  [{'name': 'subject', 'value': 'Iraq War (2003-...
# 197  [{'name': 'persons', 'value': 'Floyd, George (...
# 198  [{'name': 'subject', 'value': 'Art', 'rank': 1...
# 199  [{'name': 'subject', 'value': 'Movies', 'rank'...
#
#                      pub_date document_type   news_desk  ...  \
# 0    2015-07-20T10:53:05+0000       article     Culture  ...
# 1    2018-03-30T21:31:00+0000       article    Business  ...
# 2    2020-08-13T22:14:24+0000       article  Washington  ...
# 3    2020-07-30T11:26:42+0000       article    Politics  ...
# 4    2020-08-04T15:29:25+0000       article    Business  ...
# ..                        ...           ...         ...  ...
# 195  2016-06-23T00:50:24+0000       article      Sports  ...
# 196  2022-02-10T21:21:24+0000       article        OpEd  ...
# 197  2020-05-29T23:48:27+0000       article    National  ...
# 198  2013-04-09T18:38:32+0000       article              ...
# 199  2013-10-03T22:29:10+0000       article     Weekend  ...
#
#                                headline.print_headline headline.name  \
# 0                   Verbier Festival Recovers in Style          None
# 1    It Nourishes the Continent. Now Its Lifeblood ...          None
# 2                                                 None          None
# 3                                                 None          None
# 4           Borrowing Is Cheap. The Catch? Qualifying.          None
# ..                                                 ...           ...
# 195                  With Late Goal,  Iceland Advances          None
# 196                       U.S. Forces Should Exit Iraq          None
# 197    Fatal Encounter Wasn’t First Time Paths Crossed          None
# 198      Renault Shows Concept At Milan Furniture Fair          None
# 199             Sell Them Trees, Then Steal Them Blind          None
#
#     headline.seo headline.sub  \
# 0           None         None
# 1           None         None
# 2           None         None
# 3           None         None
# 4           None         None
# ..           ...          ...
# 195         None         None
# 196         None         None
# 197         None         None
# 198         None         None
# 199         None         None
#
#                                        byline.original  \
# 0                                By James R. Oestreich
# 1                                       By Ana Swanson
# 2                                       By Edward Wong
# 3                               By Giovanni Russonello
# 4                               By Tara Siegel Bernard
# ..                                                 ...
# 195                                               None
# 196               By Trita Parsi and Adam N. Weinstein
# 197  By Matt Furber, Audra D. S. Burch and Frances ...
# 198                                     By Phil Patton
# 199                                  By Stephen Holden
#
#                                          byline.person byline.organization  \
# 0    [{'firstname': 'James', 'middlename': 'R.', 'l...                None
# 1    [{'firstname': 'Ana', 'middlename': None, 'las...                None
# 2    [{'firstname': 'Edward', 'middlename': None, '...                None
# 3    [{'firstname': 'Giovanni', 'middlename': None,...                None
# 4    [{'firstname': 'Tara', 'middlename': 'Siegel',...                None
# ..                                                 ...                 ...
# 195                                                 []                None
# 196  [{'firstname': 'Trita', 'middlename': None, 'l...                None
# 197  [{'firstname': 'Matt', 'middlename': None, 'la...                None
# 198  [{'firstname': 'Phil', 'middlename': None, 'la...                None
# 199  [{'firstname': 'Stephen', 'middlename': None, ...                None
#
#     print_section print_page  \
# 0             NaN        NaN
# 1               B          1
# 2             NaN        NaN
# 3             NaN        NaN
# 4               B          1
# ..            ...        ...
# 195             B         10
# 196             A         26
# 197             A          1
# 198            AU          3
# 199             C         15
#
#                                                  title
# 0    Review: Verbier Festival Recovers in Style wit...
# 1    It’s Factory North America,’ but Trump Could H...
# 2    U.S. Labels Chinese Language Education Group a...
# 3                         Obama (Privately) Slams Trum
# 4    Interest Rates Are Low, but Loans Are Harder t...
# ..                                                 ...
# 195            Iceland Advances at Euros With Late Goa
# 196              Why Are American Troops Still in Iraq
# 197  What Happened in the Chaotic Moments Before Ge...
# 198  Renault Shows Edgy Concept at Milan Furniture Fai
# 199              Sell Them Trees, Then Steal Them Blin
#
# [200 rows x 29 columns]

# %%
print(reviews_df['title'])
# Out:
# 0      Review: Verbier Festival Recovers in Style wit...
# 1      It’s Factory North America,’ but Trump Could H...
# 2      U.S. Labels Chinese Language Education Group a...
# 3                           Obama (Privately) Slams Trum
# 4      Interest Rates Are Low, but Loans Are Harder t...
#                              ...
# 195              Iceland Advances at Euros With Late Goa
# 196                Why Are American Troops Still in Iraq
# 197    What Happened in the Chaotic Moments Before Ge...
# 198    Renault Shows Edgy Concept at Milan Furniture Fai
# 199                Sell Them Trees, Then Steal Them Blin
# Name: title, Length: 200, dtype: object

# %%
reviews_df['keywords']
# Out:
# 0      [{'name': 'glocations', 'value': 'Switzerland'...
# 1      [{'name': 'organizations', 'value': 'Union Pac...
# 2      [{'name': 'subject', 'value': 'Chinese Languag...
# 3      [{'name': 'persons', 'value': 'Obama, Barack',...
# 4      [{'name': 'subject', 'value': 'Mortgages', 'ra...
#                              ...
# 195    [{'name': 'subject', 'value': 'Soccer', 'rank'...
# 196    [{'name': 'subject', 'value': 'Iraq War (2003-...
# 197    [{'name': 'persons', 'value': 'Floyd, George (...
# 198    [{'name': 'subject', 'value': 'Art', 'rank': 1...
# 199    [{'name': 'subject', 'value': 'Movies', 'rank'...
# Name: keywords, Length: 200, dtype: object

# %%
# Extract 'name' and 'value' from items in "keywords" column
def extract_keywords(keyword_list):
    extracted_keywords = ""
    for item in keyword_list:
        # Extract 'name' and 'value'
        keyword = f"{item['name']}: {item['value']};" 
        # Append the keyword item to the extracted_keywords list
        extracted_keywords += keyword
    return extracted_keywords

# Fix the "keywords" column by converting cells from a list to a string
reviews_df['keywords'] = reviews_df['keywords'].apply(extract_keywords)

reviews_df
# Out:
#                                               abstract  \
# 0    The Swiss event replaced James Levine with the...
# 1    What the journey of a Union Pacific locomotive...
# 2    State Department officials said the move was a...
# 3    Raking in cash for Biden, the former president...
# 4    Banks have tightened standards, becoming more ...
# ..                                                 ...
# 195  Iceland, the smallest nation ever to compete a...
# 196  The U.S. withdrew its forces from Afghanistan ...
# 197  The episode began with a report of a $20 count...
# 198  Ross Lovegrove, a British product designer, te...
# 199  Paul Giamatti and Paul Rudd play professional ...
#
#                                                web_url  \
# 0    https://www.nytimes.com/2015/07/21/arts/intern...
# 1    https://www.nytimes.com/2018/03/30/business/ec...
# 2    https://www.nytimes.com/2020/08/13/us/politics...
# 3    https://www.nytimes.com/2020/07/30/us/politics...
# 4    https://www.nytimes.com/2020/08/04/your-money/...
# ..                                                 ...
# 195  https://www.nytimes.com/2016/06/23/sports/socc...
# 196  https://www.nytimes.com/2022/02/10/opinion/bid...
# 197  https://www.nytimes.com/2020/05/29/us/derek-ch...
# 198  https://wheels.blogs.nytimes.com/2013/04/09/re...
# 199  https://www.nytimes.com/2013/10/04/movies/all-...
#
#                                                snippet  \
# 0    The Swiss event replaced James Levine with the...
# 1    What the journey of a Union Pacific locomotive...
# 2    State Department officials said the move was a...
# 3    Raking in cash for Biden, the former president...
# 4    Banks have tightened standards, becoming more ...
# ..                                                 ...
# 195  Iceland, the smallest nation ever to compete a...
# 196  The U.S. withdrew its forces from Afghanistan ...
# 197  The episode began with a report of a $20 count...
# 198  Ross Lovegrove, a British product designer, te...
# 199  Paul Giamatti and Paul Rudd play professional ...
#
#                                         lead_paragraph  \
# 0    VERBIER, Switzerland — No one could have been ...
# 1    CHICAGO — If North America were a factory, Uni...
# 2    WASHINGTON — The State Department announced on...
# 3    Obama takes the gloves off for Biden, and Cong...
# 4    As public school teachers, Tori Smith and her ...
# ..                                                 ...
# 195  A late winning goal. A spot in the knockout st...
# 196  U.S. troops in Iraq quietly thwarted two separ...
# 197  MINNEAPOLIS — One was a veteran of the Minneap...
# 198  Renault unveiled a striking blue concept car b...
# 199  The wry tone of “All Is Bright,” a sardonic, s...
#
#                            source  \
# 0    International New York Times
# 1              The New York Times
# 2              The New York Times
# 3              The New York Times
# 4              The New York Times
# ..                            ...
# 195            The New York Times
# 196            The New York Times
# 197            The New York Times
# 198            The New York Times
# 199            The New York Times
#
#                                             multimedia  \
# 0    [{'rank': 0, 'subtype': 'watch308', 'caption':...
# 1    [{'rank': 0, 'subtype': 'xlarge', 'caption': N...
# 2    [{'rank': 0, 'subtype': 'xlarge', 'caption': N...
# 3    [{'rank': 0, 'subtype': 'xlarge', 'caption': N...
# 4    [{'rank': 0, 'subtype': 'xlarge', 'caption': N...
# ..                                                 ...
# 195  [{'rank': 0, 'subtype': 'watch308', 'caption':...
# 196  [{'rank': 0, 'subtype': 'xlarge', 'caption': N...
# 197  [{'rank': 0, 'subtype': 'xlarge', 'caption': N...
# 198                                                 []
# 199  [{'rank': 0, 'subtype': 'wide', 'caption': Non...
#
#                                               keywords  \
# 0    glocations: Switzerland;organizations: Metropo...
# 1    organizations: Union Pacific Corporation;subje...
# 2    subject: Chinese Language;subject: Foreign Stu...
# 3    persons: Obama, Barack;persons: Biden, Joseph ...
# 4    subject: Mortgages;subject: Credit and Debt;su...
# ..                                                 ...
# 195  subject: Soccer;glocations: Iceland;glocations...
# 196  subject: Iraq War (2003-11);subject: Afghanist...
# 197  persons: Floyd, George (d 2020);persons: Chauv...
# 198  subject: Art;subject: Automobiles;subject: Des...
# 199  subject: Movies;persons: Rudd, Paul;persons: G...
#
#                      pub_date document_type   news_desk  ...  \
# 0    2015-07-20T10:53:05+0000       article     Culture  ...
# 1    2018-03-30T21:31:00+0000       article    Business  ...
# 2    2020-08-13T22:14:24+0000       article  Washington  ...
# 3    2020-07-30T11:26:42+0000       article    Politics  ...
# 4    2020-08-04T15:29:25+0000       article    Business  ...
# ..                        ...           ...         ...  ...
# 195  2016-06-23T00:50:24+0000       article      Sports  ...
# 196  2022-02-10T21:21:24+0000       article        OpEd  ...
# 197  2020-05-29T23:48:27+0000       article    National  ...
# 198  2013-04-09T18:38:32+0000       article              ...
# 199  2013-10-03T22:29:10+0000       article     Weekend  ...
#
#                                headline.print_headline headline.name  \
# 0                   Verbier Festival Recovers in Style          None
# 1    It Nourishes the Continent. Now Its Lifeblood ...          None
# 2                                                 None          None
# 3                                                 None          None
# 4           Borrowing Is Cheap. The Catch? Qualifying.          None
# ..                                                 ...           ...
# 195                  With Late Goal,  Iceland Advances          None
# 196                       U.S. Forces Should Exit Iraq          None
# 197    Fatal Encounter Wasn’t First Time Paths Crossed          None
# 198      Renault Shows Concept At Milan Furniture Fair          None
# 199             Sell Them Trees, Then Steal Them Blind          None
#
#     headline.seo headline.sub  \
# 0           None         None
# 1           None         None
# 2           None         None
# 3           None         None
# 4           None         None
# ..           ...          ...
# 195         None         None
# 196         None         None
# 197         None         None
# 198         None         None
# 199         None         None
#
#                                        byline.original  \
# 0                                By James R. Oestreich
# 1                                       By Ana Swanson
# 2                                       By Edward Wong
# 3                               By Giovanni Russonello
# 4                               By Tara Siegel Bernard
# ..                                                 ...
# 195                                               None
# 196               By Trita Parsi and Adam N. Weinstein
# 197  By Matt Furber, Audra D. S. Burch and Frances ...
# 198                                     By Phil Patton
# 199                                  By Stephen Holden
#
#                                          byline.person byline.organization  \
# 0    [{'firstname': 'James', 'middlename': 'R.', 'l...                None
# 1    [{'firstname': 'Ana', 'middlename': None, 'las...                None
# 2    [{'firstname': 'Edward', 'middlename': None, '...                None
# 3    [{'firstname': 'Giovanni', 'middlename': None,...                None
# 4    [{'firstname': 'Tara', 'middlename': 'Siegel',...                None
# ..                                                 ...                 ...
# 195                                                 []                None
# 196  [{'firstname': 'Trita', 'middlename': None, 'l...                None
# 197  [{'firstname': 'Matt', 'middlename': None, 'la...                None
# 198  [{'firstname': 'Phil', 'middlename': None, 'la...                None
# 199  [{'firstname': 'Stephen', 'middlename': None, ...                None
#
#     print_section print_page  \
# 0             NaN        NaN
# 1               B          1
# 2             NaN        NaN
# 3             NaN        NaN
# 4               B          1
# ..            ...        ...
# 195             B         10
# 196             A         26
# 197             A          1
# 198            AU          3
# 199             C         15
#
#                                                  title
# 0    Review: Verbier Festival Recovers in Style wit...
# 1    It’s Factory North America,’ but Trump Could H...
# 2    U.S. Labels Chinese Language Education Group a...
# 3                         Obama (Privately) Slams Trum
# 4    Interest Rates Are Low, but Loans Are Harder t...
# ..                                                 ...
# 195            Iceland Advances at Euros With Late Goa
# 196              Why Are American Troops Still in Iraq
# 197  What Happened in the Chaotic Moments Before Ge...
# 198  Renault Shows Edgy Concept at Milan Furniture Fai
# 199              Sell Them Trees, Then Steal Them Blin
#
# [200 rows x 29 columns]

# %%
# Create a list from the "title" column using to_list()
# These titles will be used in the query for The Movie Database
title_list = reviews_df['title'].to_list()
title_list
# Out:
# ['Review: Verbier Festival Recovers in Style with Finnish Maestr',
#  'It’s Factory North America,’ but Trump Could Hobble I',
#  'U.S. Labels Chinese Language Education Group a Diplomatic Missio',
#  'Obama (Privately) Slams Trum',
#  'Interest Rates Are Low, but Loans Are Harder to Get. Here’s Why',
#  'The Voice’ and ‘Gentefied',
#  'This Is Not Tom Brady’s Epilogu',
#  'Pop and Rock Listings for March 29-April ',
#  'The Evangelical Case Against Judge Kavanaug',
#  'Here’s Another Fun Thing You Can Do',
#  'Suntan,’ and Refusing to Let G',
#  'After F.B.I.’s Inquiry Into Omar Mateen, a Focus on What Else Could Be Don',
#  'Brett Howden Stands Out in the Rangers’ Youth Movemen',
#  'It’s Him, Not He',
#  'Supreme Court, Republican Party, Poland: Your Wednesday Evening Briefin',
#  'Betting on Default',
#  'With Inflation, Workers Are Facing Return-to-Office Sticker Shoc',
#  'Covid Forces Families to Rethink Nursing Home Car',
#  'Killer Robots.',
#  'Wonder Woman and Her Evolving Loo',
#  'Giants Add a Center, the First Taken in the Draf',
#  'No Chianti, but Plenty to Chew O',
#  'Spelling Bee Foru',
#  'Celebrating America, Scoop by Frosty Scoo',
#  'Vita Vea Is a Defensive Minimalist With Maximum N.F.L. Impac',
#  'The Daily’: Kris Kobach’s Quest Against Voter Frau',
#  'The Benefits of Mixing Rich and Poo',
#  'Classy Dinosaur’ Wedding Came Leukemia and I.V.F',
#  "Reality Check for Old Masters at Sotheby'",
#  'Monday’s Travel News and Tip',
#  'Food Quality Trumps Variety, Experts Sa',
#  'Is New York City Ready for the Omicron Variant',
#  'An Olympic Champion Hopes Runners Learn From His Head Injurie',
#  'N.S.A. and Other Matters Leave McConnell’s Senate in Disarra',
#  'Recent Commercial Real Estate Transaction',
#  'Pushing the Frontiers of Mechanical Desig',
#  'In Niger, Where U.S. Troops Died, a Lawless and Shifting Landscap',
#  'Ganga Stone, Who Gave Sustenance to AIDS Patients, Dies at 7',
#  'For Wares, Games Have Been Tough to Watc',
#  'Feel Good Sensation',
#  'Your Next Necklace May Have Gold From an Old Phon',
#  'Whitney Inaugurates New Museum with Dinne',
#  'The Breakout Stars of 202',
#  'Personality Change May Be Early Sign of Dementia, Experts Sa',
#  'Biden Issues Executive Order on Abortion Access, Calling for More Stud',
#  'Lawmakers Say Puff Bar Used Pandemic to Market to Teen',
#  'The Bank That Kept Saying Yes to Trum',
#  'moral distress.',
#  'Michael Flynn Moves to Withdraw Guilty Plea in About-Face After Extensive Cooperatio',
#  'The Thing About Jellyfish,’ by Ali Benjami',
#  'Spain’s Conquest of America as Oper',
#  'My Illness, the Third Partner in Our Relationshi',
#  'First Vaccine for Dengue Fever Shows Promise in 2nd Big Tria',
#  'A Song of the Sea, in Gold and Gem',
#  'Deadwood’ and Other Dark Roles, Dies at 6',
#  'The Danger of an Incurious Presiden',
#  'Think Amazon’s Drone Delivery Idea Is a Gimmick? Think Agai',
#  'Tech’s Biggest Companies Discover Austerity, to the Relief of Investor',
#  'Does American Society Need Abortion',
#  'Phillies-Blue Jays Games Postponed After 2 Staff Members Test Positiv',
#  '$50,000 for Meshell Ndegeocello and 33 Other U.S.A. Fellow',
#  'A Land Art Pioneer’s Adventures in Time and Spac',
#  'Maoists Block Deal to Break Nepal’s Long Political Deadloc',
#  'Audree Norton, Who Paved Way for Deaf Actors, Dies at 8',
#  'Sculpture of Winged Bull Destroyed by ISIS Is Recreated for London’s Fourth Plint',
#  'Serena Williams and Andy Murray in Wimbledon Mixed Doubles: It’s Happenin',
#  'Senate Democrats Press G.O.P. to Fully Fund Amtra',
#  'U.S. Will Send 300 Advisers to Ira',
#  'Debt. Terror. Politics. To Seattle Millennials, the Future Looks Scary',
#  'With His Career Winding Down, Iginla Focuses on Winning a Stanley Cu',
#  'Patriots Kicker Once Also Made Impression With His Ar',
#  'Message Sent: 21 and Counting for Michael Phelp',
#  'Extended-Stay Hotels Climb in Manhatta',
#  'New York Today: Winging I',
#  'Inside the Governors Ball, the Official Oscars After-Part',
#  'After Covid Diagnosis, a Conservative Radio Host Sends a New Messag',
#  'New Cape Town Museum to Focus on Contemporary African Ar',
#  'Mass Shootings Don’t Have to Be Inevitabl',
#  'One Way to Cheer Up: Cheer Harde',
#  'Pretend It’s Alien',
#  'A Louis Vuitton Chronograph Timepiece Inspired by Motor Racin',
#  'How American Jews Feel About Israe',
#  'Opioids on the Qua',
#  'Joe Biden’s Run Has Late Night Looking for a Figh',
#  'Vatican Extends Deal With China Over Appointment of Bishop',
#  'Quotation of the Day: For Black NASCAR Fans, It Can Be Lonely at the Trac',
#  'Whistle-Blower, Boeing, Labradoodles: Your Thursday Evening Briefin',
#  'The Champions League Returns With a Plan for Everythin',
#  'Pinterest Posts Narrower Loss, but Falls Short of Wall St. Estimate',
#  'A Middle-Class Oasis in New York Is Spared',
#  'Too Many Colonoscopies in the Elderl',
#  'Flitting Through Fleeting Encounter',
#  'Word of the Day + Quiz | exorcis',
#  'Knicks Try to Keep Pace in Beefed-Up Eastern Conferenc',
#  'How a Food, Drink and Lifestyle Expert Spends His Sunday',
#  'The Early Years of Stockholm’s Mega Home-Design Stor',
#  'Aretha Franklin on Singing for Pope Francis and Her Next Albu',
#  'Is This Frog a Hate Symbol or Not',
#  'Elvis,’ as Remixed by Baz Luhrman',
#  'College Financial Ai',
#  'A New Salmon Jerky for Snackin',
#  'How to Destroy the Business Model of Breitbart and Fake New',
#  'The Athletic Lays Off 8 Percent of Staf',
#  'How to Fight Polio With Cultural Sensitivit',
#  'Business Reaches a Turning Poin',
#  'As Primaries Wind Down, Here’s a Look at the Performance of Trump’s Candidate',
#  'It’s Never Our Time’: First-Time Home Buyers Face a Brutal Marke',
#  'David Cross: Oh, Come On',
#  'Bernie Sanders Draws Union Support Pressing Pensions Issu',
#  'The Past Pushes Back in 2 Shows With Contemporary Blackness in Min',
#  'Today in Politic',
#  'Reimagining Rice, From the Mekong to the Mississipp',
#  'Di Maio Quits as Five Star Leader in Italy, Deepening Party’s Disarra',
#  'The Agony of Ecstas',
#  'Anglo-Irish Retailer Primark to Make U.S. Landfall in Bosto',
#  'Ideal, Perfect, Ultimate: What Drives Parents to Seek the Unattainable',
#  'Dick Cavett: By the Boo',
#  'Ohio Woman Convicted of Murder in 1993 Death of Newbor',
#  'Mardy Fish Ends Hiatus but Falls at Indian Wells',
#  'Why You Should Take Time to Mourn During Career Transition',
#  'Obama and Paul Ryan Have Lunch, and Consider a Wary Truc',
#  'Miley Cyrus Goes Modest in a Fitted Dres',
#  'Daughter of the Nile’: Baffling, Beautiful and Newly Restore',
#  'Zelensky urges the E.U. to create a war tribunal as he accepts the Sakharov Prize',
#  'Serena Williams Forced Her Way Into the Tennis History Book',
#  'Why Seven Republican Senators Voted to Convict Trum',
#  'U.S. Swap for Bergdahl Shook Up Secret Talks With Cub',
#  'Your Thursday Briefin',
#  'Omnipresent’ Leader Won’t Run Again. But Will He Relinquish Power',
#  'Coach, Husband, Architect, Father. One Title Was a Fake',
#  'Extremely Dangerous Major’ Stor',
#  'Fulton Mall, Amid Chang',
#  'The Only Realistic Way to Fix Campaign Financ',
#  'Tennessee Bans Drag Shows on Public Propert',
#  'Endemic’: The Travel Industry Readies for a New Phas',
#  'Loved by a King, but Doomed by a Hermi',
#  'Bolton and Pompeo March to Wa',
#  'Now It Can Be Told: How Neil Sheehan Got the Pentagon Paper',
#  'Moody’s Lowers the Metropolitan Opera’s Credit Ratin',
#  'Playing With a Full Deck, and Your Hea',
#  'The Day the Dinghy Got Awa',
#  'Ted Lerner, 97, Dies; Developer Bought and Built Washington National',
#  'Fed, Pressed by Trump to Cut Rates, Faces Fire No Matter What It Doe',
#  'Mexico: Discovery of Coca Plants Puzzles Authoritie',
#  'American Allies and Adversaries Urge Caution on North Kore',
#  'New Position for Angels: Contentio',
#  'House Hunting in … Spai',
#  'Mom’s Doll Needs a New Dres',
#  'Kansas Governor Vetoes Medicaid Expansion, Setting Stage for Showdow',
#  'Amid Officials’ Lockout, a Call Costs the Red Bull',
#  'Uber and Lyft Charge Toward Potential I.P.O.s Next Yea',
#  'Ponzi’s Scheme',
#  'Thursday and Friday’s Partial Lunar Eclipse Was the Longest in 580 Year',
#  'Smog, Fraud and Diplomac',
#  'Inside N.B.A. and Out, Words of Support (Mostly) for Collins’s Revelatio',
#  'What’s on Saturda',
#  'Bear Stearns Emails Show Its Financing Breaking Awa',
#  'Comedy Listings for Dec. 5-Dec. 1',
#  'Bill Cunningham | Fringe Movemen',
#  'Chick-fil-A Commits to Stop Sales of Poultry Raised With Antibiotic',
#  'Who Should Get Reparations in California',
#  'Islanders Rally for Tense Victory Over Ranger',
#  'The Most Detailed Map of Gay Marriage in Americ',
#  'Novak Djokovic, Great at Tennis and Bad at Science, Awaits His Fat',
#  'SALT Tax Increase That Burned Blue States is Targeted by Democrat',
#  'Getting Married Is Better Than Dying, Right',
#  'The Ad Campaign: Quinn Takes Aim at de Blasi',
#  'He Was Supposed to Take a Phot',
#  'New Drug May Help Some Asthmatics, Study Find',
#  'Spending and Growth, 2009-1',
#  'Wheelies: The Electro-Caddy Editio',
#  'Two Mets Collide in 13th and Giants are Left Standin',
#  'Cyclone Fani Strikes, Heading in the Path of Tens of Millions in Indi',
#  'Felix Auger-Aliassime Picks Up Where Denis Shapovalov Left Of',
#  'Welsh Make Their Case for Lions Squa',
#  'Joe Biden Announces 2020 Run for President, After Months of Hesitatio',
#  'Cyprus Deal Sparks Anti-German Mood — and Defender',
#  'Review: Yuja Wang Plays Dazed Chaos, Then 7 Encore',
#  'Susan Collins Was Never Going to Los',
#  'Interrogation of Bin Laden Relative Is Recounte',
#  'Tying Music to Works on the Museum Wal',
#  'The Fight Against Al Shaba',
#  'White House Struggles on Immigration Rulin',
#  'Trump’s Latest Dinner Guest: Nick Fuentes, White Supremacis',
#  'The Men’s Final Remains in Familiar Hand',
#  'Word of the Day: deleteriou',
#  'How Elizabeth Warren Responded to Mark Zuckerberg’s Criticism, on Twitte',
#  'Quotation of the Da',
#  'After a Rocky Start, Stan Wawrinka Storms Into His First U.S. Open Fina',
#  'IBM Sets Announcement on Monday, Possibly on Chip-Making Uni',
#  'Motive in Boulder Shooting Is Still a Mystery, Police Sa',
#  'C.B.O. Warns of Possible Default Between July and Septembe',
#  'Diapers, Cereal and, Yes, Toilet Paper Are Going to Get More Expensiv',
#  'Syrian Rebels Depart Homs District Under Dea',
#  'To Win a Free I.V.F. Cycle, Contestants Share Losses, Grief and Hope. Is it Worth It',
#  'Iceland Advances at Euros With Late Goa',
#  'Why Are American Troops Still in Iraq',
#  'What Happened in the Chaotic Moments Before George Floyd Die',
#  'Renault Shows Edgy Concept at Milan Furniture Fai',
#  'Sell Them Trees, Then Steal Them Blin']

# %% [markdown]
# ### Access The Movie Database API

# %%
# Prepare The Movie Database query
nyt_api_key = os.getenv('NYT')
tmdb_api_key = os.getenv('TMDB')

url = "https://api.themoviedb.org/3/search/movie?query="
tmdb_key_string = "&api_key=" + tmdb_api_key

# %%
    # Perform a "GET" request for The Movie Database
reviews = requests.get(author_query_url + author)

    # Include a try clause to search for the full movie details.
    # Use the except clause to print out a statement if a movie
    # is not found.


# Create an empty list to store the results
tmdb_movies_list = []

# Create a request counter to sleep the requests after a multiple
# of 50 requests
request_counter = 0

# Loop through the titles
for title in title_list:
    # Check if we need to sleep before making a request
    if request_counter % 50 == 0 and request_counter != 0:
        time.sleep(1)  # Sleep for 1 second after every 50 requests

    # Increment the request counter
    request_counter += 1

    # Perform a "GET" request to The Movie Database
    results = requests.get(query_url_with_page).json()
    response = requests.get(f"{url}?api_key={tmdb_key_string}&query={title}")
    response_data = response.json()

    try:
        # Get movie ID
        movie_ID = response_data['results'][0]['id']
        
        # Make a request for the full movie details
        details_url = f"https://api.themoviedb.org/3/movie/{movie_ID}?api_key={tmdb_key_string}"
        full_response = requests.get(details_url)
        full_data = full_response.json()

        # Extract relevant details
        genres = [genre['name'] for genre in full_data.get('genres', [])]
        spoken_languages = [lang['english_name'] for lang in full_data.get('spoken_languages', [])]
        production_countries = [country['name'] for country in full_data.get('production_countries', [])]

        # Store the relevant data in a dictionary
        movie_info = {
            "title": title,
            "genres": genres,
            "spoken_languages": spoken_languages,
            "production_countries": production_countries
        }

        # Append the dictionary to the results list
        mov_results_list.append(movie_info)

        # Print out the title that was found
        print(f"Found {title}")

    except (IndexError, KeyError):
        # Handle the case where the movie is not found or there is an issue with the response
        print(f"{title} not found or there was an error retrieving the data.")

# The mov_results_list now contains the extracted movie data
# Out:
# Review: Verbier Festival Recovers in Style with Finnish Maestr not found or there was an error retrieving the data.
# It’s Factory North America,’ but Trump Could Hobble I not found or there was an error retrieving the data.
# U.S. Labels Chinese Language Education Group a Diplomatic Missio not found or there was an error retrieving the data.
# Obama (Privately) Slams Trum not found or there was an error retrieving the data.
# Interest Rates Are Low, but Loans Are Harder to Get. Here’s Why not found or there was an error retrieving the data.
# The Voice’ and ‘Gentefied not found or there was an error retrieving the data.
# This Is Not Tom Brady’s Epilogu not found or there was an error retrieving the data.
# Pop and Rock Listings for March 29-April  not found or there was an error retrieving the data.
# The Evangelical Case Against Judge Kavanaug not found or there was an error retrieving the data.
# Here’s Another Fun Thing You Can Do not found or there was an error retrieving the data.
# Suntan,’ and Refusing to Let G not found or there was an error retrieving the data.
# After F.B.I.’s Inquiry Into Omar Mateen, a Focus on What Else Could Be Don not found or there was an error retrieving the data.
# Brett Howden Stands Out in the Rangers’ Youth Movemen not found or there was an error retrieving the data.
# Found It’s Him, Not He
# Supreme Court, Republican Party, Poland: Your Wednesday Evening Briefin not found or there was an error retrieving the data.
# Betting on Default not found or there was an error retrieving the data.
# With Inflation, Workers Are Facing Return-to-Office Sticker Shoc not found or there was an error retrieving the data.
# Covid Forces Families to Rethink Nursing Home Car not found or there was an error retrieving the data.
# Found Killer Robots.
# Wonder Woman and Her Evolving Loo not found or there was an error retrieving the data.
# Giants Add a Center, the First Taken in the Draf not found or there was an error retrieving the data.
# No Chianti, but Plenty to Chew O not found or there was an error retrieving the data.
# Spelling Bee Foru not found or there was an error retrieving the data.
# Celebrating America, Scoop by Frosty Scoo not found or there was an error retrieving the data.
# Vita Vea Is a Defensive Minimalist With Maximum N.F.L. Impac not found or there was an error retrieving the data.
# The Daily’: Kris Kobach’s Quest Against Voter Frau not found or there was an error retrieving the data.
# The Benefits of Mixing Rich and Poo not found or there was an error retrieving the data.
# Classy Dinosaur’ Wedding Came Leukemia and I.V.F not found or there was an error retrieving the data.
# Reality Check for Old Masters at Sotheby' not found or there was an error retrieving the data.
# Monday’s Travel News and Tip not found or there was an error retrieving the data.
# Food Quality Trumps Variety, Experts Sa not found or there was an error retrieving the data.
# Is New York City Ready for the Omicron Variant not found or there was an error retrieving the data.
# An Olympic Champion Hopes Runners Learn From His Head Injurie not found or there was an error retrieving the data.
# N.S.A. and Other Matters Leave McConnell’s Senate in Disarra not found or there was an error retrieving the data.
# Recent Commercial Real Estate Transaction not found or there was an error retrieving the data.
# Pushing the Frontiers of Mechanical Desig not found or there was an error retrieving the data.
# In Niger, Where U.S. Troops Died, a Lawless and Shifting Landscap not found or there was an error retrieving the data.
# Ganga Stone, Who Gave Sustenance to AIDS Patients, Dies at 7 not found or there was an error retrieving the data.
# For Wares, Games Have Been Tough to Watc not found or there was an error retrieving the data.
# Feel Good Sensation not found or there was an error retrieving the data.
# Your Next Necklace May Have Gold From an Old Phon not found or there was an error retrieving the data.
# Whitney Inaugurates New Museum with Dinne not found or there was an error retrieving the data.
# The Breakout Stars of 202 not found or there was an error retrieving the data.
# Personality Change May Be Early Sign of Dementia, Experts Sa not found or there was an error retrieving the data.
# Biden Issues Executive Order on Abortion Access, Calling for More Stud not found or there was an error retrieving the data.
# Lawmakers Say Puff Bar Used Pandemic to Market to Teen not found or there was an error retrieving the data.
# The Bank That Kept Saying Yes to Trum not found or there was an error retrieving the data.
# moral distress. not found or there was an error retrieving the data.
# Michael Flynn Moves to Withdraw Guilty Plea in About-Face After Extensive Cooperatio not found or there was an error retrieving the data.
# The Thing About Jellyfish,’ by Ali Benjami not found or there was an error retrieving the data.
# Spain’s Conquest of America as Oper not found or there was an error retrieving the data.
# My Illness, the Third Partner in Our Relationshi not found or there was an error retrieving the data.
# First Vaccine for Dengue Fever Shows Promise in 2nd Big Tria not found or there was an error retrieving the data.
# A Song of the Sea, in Gold and Gem not found or there was an error retrieving the data.
# Deadwood’ and Other Dark Roles, Dies at 6 not found or there was an error retrieving the data.
# The Danger of an Incurious Presiden not found or there was an error retrieving the data.
# Think Amazon’s Drone Delivery Idea Is a Gimmick? Think Agai not found or there was an error retrieving the data.
# Tech’s Biggest Companies Discover Austerity, to the Relief of Investor not found or there was an error retrieving the data.
# Does American Society Need Abortion not found or there was an error retrieving the data.
# Phillies-Blue Jays Games Postponed After 2 Staff Members Test Positiv not found or there was an error retrieving the data.
# $50,000 for Meshell Ndegeocello and 33 Other U.S.A. Fellow not found or there was an error retrieving the data.
# A Land Art Pioneer’s Adventures in Time and Spac not found or there was an error retrieving the data.
# Maoists Block Deal to Break Nepal’s Long Political Deadloc not found or there was an error retrieving the data.
# Audree Norton, Who Paved Way for Deaf Actors, Dies at 8 not found or there was an error retrieving the data.
# Sculpture of Winged Bull Destroyed by ISIS Is Recreated for London’s Fourth Plint not found or there was an error retrieving the data.
# Serena Williams and Andy Murray in Wimbledon Mixed Doubles: It’s Happenin not found or there was an error retrieving the data.
# Senate Democrats Press G.O.P. to Fully Fund Amtra not found or there was an error retrieving the data.
# U.S. Will Send 300 Advisers to Ira not found or there was an error retrieving the data.
# Debt. Terror. Politics. To Seattle Millennials, the Future Looks Scary not found or there was an error retrieving the data.
# With His Career Winding Down, Iginla Focuses on Winning a Stanley Cu not found or there was an error retrieving the data.
# Patriots Kicker Once Also Made Impression With His Ar not found or there was an error retrieving the data.
# Message Sent: 21 and Counting for Michael Phelp not found or there was an error retrieving the data.
# Extended-Stay Hotels Climb in Manhatta not found or there was an error retrieving the data.
# New York Today: Winging I not found or there was an error retrieving the data.
# Inside the Governors Ball, the Official Oscars After-Part not found or there was an error retrieving the data.
# After Covid Diagnosis, a Conservative Radio Host Sends a New Messag not found or there was an error retrieving the data.
# New Cape Town Museum to Focus on Contemporary African Ar not found or there was an error retrieving the data.
# Mass Shootings Don’t Have to Be Inevitabl not found or there was an error retrieving the data.
# One Way to Cheer Up: Cheer Harde not found or there was an error retrieving the data.
# Pretend It’s Alien not found or there was an error retrieving the data.
# A Louis Vuitton Chronograph Timepiece Inspired by Motor Racin not found or there was an error retrieving the data.
# How American Jews Feel About Israe not found or there was an error retrieving the data.
# Opioids on the Qua not found or there was an error retrieving the data.
# Joe Biden’s Run Has Late Night Looking for a Figh not found or there was an error retrieving the data.
# Vatican Extends Deal With China Over Appointment of Bishop not found or there was an error retrieving the data.
# Quotation of the Day: For Black NASCAR Fans, It Can Be Lonely at the Trac not found or there was an error retrieving the data.
# Whistle-Blower, Boeing, Labradoodles: Your Thursday Evening Briefin not found or there was an error retrieving the data.
# The Champions League Returns With a Plan for Everythin not found or there was an error retrieving the data.
# Pinterest Posts Narrower Loss, but Falls Short of Wall St. Estimate not found or there was an error retrieving the data.
# A Middle-Class Oasis in New York Is Spared not found or there was an error retrieving the data.
# Too Many Colonoscopies in the Elderl not found or there was an error retrieving the data.
# Flitting Through Fleeting Encounter not found or there was an error retrieving the data.
# Word of the Day + Quiz | exorcis not found or there was an error retrieving the data.
# Knicks Try to Keep Pace in Beefed-Up Eastern Conferenc not found or there was an error retrieving the data.
# How a Food, Drink and Lifestyle Expert Spends His Sunday not found or there was an error retrieving the data.
# The Early Years of Stockholm’s Mega Home-Design Stor not found or there was an error retrieving the data.
# Aretha Franklin on Singing for Pope Francis and Her Next Albu not found or there was an error retrieving the data.
# Is This Frog a Hate Symbol or Not not found or there was an error retrieving the data.
# Elvis,’ as Remixed by Baz Luhrman not found or there was an error retrieving the data.
# College Financial Ai not found or there was an error retrieving the data.
# A New Salmon Jerky for Snackin not found or there was an error retrieving the data.
# How to Destroy the Business Model of Breitbart and Fake New not found or there was an error retrieving the data.
# The Athletic Lays Off 8 Percent of Staf not found or there was an error retrieving the data.
# How to Fight Polio With Cultural Sensitivit not found or there was an error retrieving the data.
# Business Reaches a Turning Poin not found or there was an error retrieving the data.
# As Primaries Wind Down, Here’s a Look at the Performance of Trump’s Candidate not found or there was an error retrieving the data.
# It’s Never Our Time’: First-Time Home Buyers Face a Brutal Marke not found or there was an error retrieving the data.
# Found David Cross: Oh, Come On
# Bernie Sanders Draws Union Support Pressing Pensions Issu not found or there was an error retrieving the data.
# The Past Pushes Back in 2 Shows With Contemporary Blackness in Min not found or there was an error retrieving the data.
# Today in Politic not found or there was an error retrieving the data.
# Reimagining Rice, From the Mekong to the Mississipp not found or there was an error retrieving the data.
# Di Maio Quits as Five Star Leader in Italy, Deepening Party’s Disarra not found or there was an error retrieving the data.
# Found The Agony of Ecstas
# Anglo-Irish Retailer Primark to Make U.S. Landfall in Bosto not found or there was an error retrieving the data.
# Ideal, Perfect, Ultimate: What Drives Parents to Seek the Unattainable not found or there was an error retrieving the data.
# Dick Cavett: By the Boo not found or there was an error retrieving the data.
# Ohio Woman Convicted of Murder in 1993 Death of Newbor not found or there was an error retrieving the data.
# Mardy Fish Ends Hiatus but Falls at Indian Wells not found or there was an error retrieving the data.
# Why You Should Take Time to Mourn During Career Transition not found or there was an error retrieving the data.
# Obama and Paul Ryan Have Lunch, and Consider a Wary Truc not found or there was an error retrieving the data.
# Miley Cyrus Goes Modest in a Fitted Dres not found or there was an error retrieving the data.
# Daughter of the Nile’: Baffling, Beautiful and Newly Restore not found or there was an error retrieving the data.
# Zelensky urges the E.U. to create a war tribunal as he accepts the Sakharov Prize not found or there was an error retrieving the data.
# Serena Williams Forced Her Way Into the Tennis History Book not found or there was an error retrieving the data.
# Why Seven Republican Senators Voted to Convict Trum not found or there was an error retrieving the data.
# U.S. Swap for Bergdahl Shook Up Secret Talks With Cub not found or there was an error retrieving the data.
# Your Thursday Briefin not found or there was an error retrieving the data.
# Omnipresent’ Leader Won’t Run Again. But Will He Relinquish Power not found or there was an error retrieving the data.
# Coach, Husband, Architect, Father. One Title Was a Fake not found or there was an error retrieving the data.
# Extremely Dangerous Major’ Stor not found or there was an error retrieving the data.
# Fulton Mall, Amid Chang not found or there was an error retrieving the data.
# The Only Realistic Way to Fix Campaign Financ not found or there was an error retrieving the data.
# Tennessee Bans Drag Shows on Public Propert not found or there was an error retrieving the data.
# Endemic’: The Travel Industry Readies for a New Phas not found or there was an error retrieving the data.
# Loved by a King, but Doomed by a Hermi not found or there was an error retrieving the data.
# Bolton and Pompeo March to Wa not found or there was an error retrieving the data.
# Now It Can Be Told: How Neil Sheehan Got the Pentagon Paper not found or there was an error retrieving the data.
# Moody’s Lowers the Metropolitan Opera’s Credit Ratin not found or there was an error retrieving the data.
# Playing With a Full Deck, and Your Hea not found or there was an error retrieving the data.
# The Day the Dinghy Got Awa not found or there was an error retrieving the data.
# Ted Lerner, 97, Dies; Developer Bought and Built Washington National not found or there was an error retrieving the data.
# Fed, Pressed by Trump to Cut Rates, Faces Fire No Matter What It Doe not found or there was an error retrieving the data.
# Mexico: Discovery of Coca Plants Puzzles Authoritie not found or there was an error retrieving the data.
# American Allies and Adversaries Urge Caution on North Kore not found or there was an error retrieving the data.
# New Position for Angels: Contentio not found or there was an error retrieving the data.
# House Hunting in … Spai not found or there was an error retrieving the data.
# Mom’s Doll Needs a New Dres not found or there was an error retrieving the data.
# Kansas Governor Vetoes Medicaid Expansion, Setting Stage for Showdow not found or there was an error retrieving the data.
# Amid Officials’ Lockout, a Call Costs the Red Bull not found or there was an error retrieving the data.
# Uber and Lyft Charge Toward Potential I.P.O.s Next Yea not found or there was an error retrieving the data.
# Found Ponzi’s Scheme
# Thursday and Friday’s Partial Lunar Eclipse Was the Longest in 580 Year not found or there was an error retrieving the data.
# Smog, Fraud and Diplomac not found or there was an error retrieving the data.
# Inside N.B.A. and Out, Words of Support (Mostly) for Collins’s Revelatio not found or there was an error retrieving the data.
# What’s on Saturda not found or there was an error retrieving the data.
# Bear Stearns Emails Show Its Financing Breaking Awa not found or there was an error retrieving the data.
# Comedy Listings for Dec. 5-Dec. 1 not found or there was an error retrieving the data.
# Bill Cunningham | Fringe Movemen not found or there was an error retrieving the data.
# Chick-fil-A Commits to Stop Sales of Poultry Raised With Antibiotic not found or there was an error retrieving the data.
# Who Should Get Reparations in California not found or there was an error retrieving the data.
# Islanders Rally for Tense Victory Over Ranger not found or there was an error retrieving the data.
# The Most Detailed Map of Gay Marriage in Americ not found or there was an error retrieving the data.
# Novak Djokovic, Great at Tennis and Bad at Science, Awaits His Fat not found or there was an error retrieving the data.
# SALT Tax Increase That Burned Blue States is Targeted by Democrat not found or there was an error retrieving the data.
# Getting Married Is Better Than Dying, Right not found or there was an error retrieving the data.
# The Ad Campaign: Quinn Takes Aim at de Blasi not found or there was an error retrieving the data.
# He Was Supposed to Take a Phot not found or there was an error retrieving the data.
# New Drug May Help Some Asthmatics, Study Find not found or there was an error retrieving the data.
# Spending and Growth, 2009-1 not found or there was an error retrieving the data.
# Wheelies: The Electro-Caddy Editio not found or there was an error retrieving the data.
# Two Mets Collide in 13th and Giants are Left Standin not found or there was an error retrieving the data.
# Cyclone Fani Strikes, Heading in the Path of Tens of Millions in Indi not found or there was an error retrieving the data.
# Felix Auger-Aliassime Picks Up Where Denis Shapovalov Left Of not found or there was an error retrieving the data.
# Welsh Make Their Case for Lions Squa not found or there was an error retrieving the data.
# Joe Biden Announces 2020 Run for President, After Months of Hesitatio not found or there was an error retrieving the data.
# Cyprus Deal Sparks Anti-German Mood — and Defender not found or there was an error retrieving the data.
# Review: Yuja Wang Plays Dazed Chaos, Then 7 Encore not found or there was an error retrieving the data.
# Susan Collins Was Never Going to Los not found or there was an error retrieving the data.
# Interrogation of Bin Laden Relative Is Recounte not found or there was an error retrieving the data.
# Tying Music to Works on the Museum Wal not found or there was an error retrieving the data.
# The Fight Against Al Shaba not found or there was an error retrieving the data.
# White House Struggles on Immigration Rulin not found or there was an error retrieving the data.
# Trump’s Latest Dinner Guest: Nick Fuentes, White Supremacis not found or there was an error retrieving the data.
# The Men’s Final Remains in Familiar Hand not found or there was an error retrieving the data.
# Word of the Day: deleteriou not found or there was an error retrieving the data.
# How Elizabeth Warren Responded to Mark Zuckerberg’s Criticism, on Twitte not found or there was an error retrieving the data.
# Quotation of the Da not found or there was an error retrieving the data.
# After a Rocky Start, Stan Wawrinka Storms Into His First U.S. Open Fina not found or there was an error retrieving the data.
# IBM Sets Announcement on Monday, Possibly on Chip-Making Uni not found or there was an error retrieving the data.
# Motive in Boulder Shooting Is Still a Mystery, Police Sa not found or there was an error retrieving the data.
# C.B.O. Warns of Possible Default Between July and Septembe not found or there was an error retrieving the data.
# Diapers, Cereal and, Yes, Toilet Paper Are Going to Get More Expensiv not found or there was an error retrieving the data.
# Syrian Rebels Depart Homs District Under Dea not found or there was an error retrieving the data.
# To Win a Free I.V.F. Cycle, Contestants Share Losses, Grief and Hope. Is it Worth It not found or there was an error retrieving the data.
# Iceland Advances at Euros With Late Goa not found or there was an error retrieving the data.
# Why Are American Troops Still in Iraq not found or there was an error retrieving the data.
# What Happened in the Chaotic Moments Before George Floyd Die not found or there was an error retrieving the data.
# Renault Shows Edgy Concept at Milan Furniture Fai not found or there was an error retrieving the data.
# Sell Them Trees, Then Steal Them Blin not found or there was an error retrieving the data.

# %%
# Create an empty list to store the results
mov_results_list = []

# Create a request counter to sleep the requests after a multiple
# of 50 requests

request_counter = 0

# Loop for making requests
for i in range(100):  # Assuming 100 requests need to be made
    # Make the API request here
    request_counter += 1
    
    if request_counter % 50 == 0:
        time.sleep(1)  # Sleep for 1 second after every 50 requests

# Loop through the titles; title_list
  

    # Check if we need to sleep before making a request


    # Add 1 to the request counter

    
    # Perform a "GET" request for The Movie Database


    # Include a try clause to search for the full movie details.
    # Use the except clause to print out a statement if a movie
    # is not found.
    try:
        # Get movie id
        movie_ID = response_data['results'][0]['id']

        # Make a request for a the full movie details
        response _data = requests.get(url + titles + tmdb_key_string).json()

        # Execute "GET" request with url

        
        # Extract the genre names into a list


        # Extract the spoken_languages' English name into a list


        # Extract the production_countries' name into a list


        # Add the relevant data to a dictionary and
        # append it to the tmdb_movies_list list

        
        # Print out the title that was found
        except:
            print(titles+"not found")

# %%
# Preview the first 5 results in JSON format
# Use json.dumps with argument indent=4 to format data


# for review in results_list[:5]:
 #   print(json.dumps(results, indent=4))

# %%
# Convert the results to a DataFrame

# %% [markdown]
# ### Merge and Clean the Data for Export

# %%
# Merge the New York Times reviews and TMDB DataFrames on title

# %%
# Remove list brackets and quotation marks on the columns containing lists
# Create a list of the columns that need fixing


# Create a list of characters to remove


# Loop through the list of columns to fix

    # Convert the column to type 'str'


    # Loop through characters to remove


# Display the fixed DataFrame

# %%
# Drop "byline.person" column

# %%
# Delete duplicate rows and reset index

# %%
# Export data to CSV without the index
